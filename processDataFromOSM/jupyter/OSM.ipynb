# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
# @Date    : 2018-04-16 18:24:00
# @Author  : guanglinzhou (xdzgl812@163.com)
# @Link    : https://github.com/GuanglinZhou
# @Version : $Id$

# 获取一个表格,列名如下：
# 路名，WayID，类型(secondary)，user,version,timestamp

import os
import csv
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
tree = ET.ElementTree(file='hefei_highways.osm')
root = tree.getroot()

# %%
# 路网中有的路名仅使用了拼音，检测并剔除
def contain_zh(word):
    '''
    判断传入字符串是否包含中文
    :param word: 待判断字符串
    :return: True:包含中文  False:不包含中文
    '''
    zh_pattern = re.compile(u'[\u4e00-\u9fa5]+')
    match = zh_pattern.search(word)
    return match

# %%
roadNameSet=set()
# 返回路网中所有路名
def getRoadNameSet(tree):
    num=0
    roadTypeList = ['primary', 'primary_link', 'secondary', 'secondary_link', 'tertiary', 'tertiary_link', 'trunk',
                    'trunk_link']
    for elem in tree.iter(tag='way'):
        print('id:')
        print(elem.attrib['id'])
        tag_k = elem.findall('tag')
        for tag in tag_k:
            print(tag.attrib)
            if ((tag.attrib['k'] == 'highway') and (tag.attrib['v'] not in roadTypeList)):
                break
            if (tag.attrib['k'] == 'name'):
                roadName = tag.attrib['v']
                if('公交通道7' in roadName):
                    print(roadName)
                    break
                if (contain_zh(roadName)):
                    roadNameSet.add(roadName)
        num+=1
#         if(num==10):
#             break
    return roadNameSet

# %%
getRoadNameSet(tree)
# Out:
# id:
# 23221072
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 23221108
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 23221143
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 23221162
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 23221215
# {'k': 'highway', 'v': 'motorway'}
# id:
# 23221216
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 23221220
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 24568371
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '翡翠路'}
# {'k': 'name:en', 'v': 'Feicui Road'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 24568374
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '青阳路'}
# {'k': 'name:en', 'v': 'Qingyang Rd.'}
# id:
# 24568378
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '延安路'}
# {'k': 'name:en', 'v': "Yan'an Rd."}
# id:
# 24568385
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '凤凰桥路'}
# {'k': 'name:en', 'v': 'Fenghuangqiao Rd.'}
# id:
# 24568386
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 24568390
# {'k': 'highway', 'v': 'primary'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'name', 'v': '明光路'}
# {'k': 'name:en', 'v': 'Mingguang Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 24568401
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '桐城路'}
# {'k': 'name:en', 'v': 'Tongcheng Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 24568405
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '大连路'}
# {'k': 'name:en', 'v': 'Dalian Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 24568420
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 24568426
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '霍邱路'}
# {'k': 'name:en', 'v': 'Huoqiu Road'}
# {'k': 'name:zh', 'v': '霍邱路'}
# {'k': 'name:zh_pinyin', 'v': 'Huòqiū Lù'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 24568427
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'int_name', 'v': 'Xi You Road'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'name', 'v': '习友南路'}
# {'k': 'name:en', 'v': 'South Xiyou Rd.'}
# {'k': 'oneway', 'v': 'no'}
# id:
# 24568429
# {'k': 'bicycle', 'v': 'yes'}
# {'k': 'cycleway', 'v': 'no'}
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'name', 'v': '石台路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 24568432
# {'k': 'highway', 'v': 'residential'}
# id:
# 24568441
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '九华山路'}
# {'k': 'name:en', 'v': 'Jiuhua Shanlu'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 24568442
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'layer', 'v': '1'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'ref', 'v': 'S351'}
# id:
# 24568451
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '清溪路'}
# {'k': 'name:en', 'v': 'Qingxi Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 24568473
# {'k': 'fixme', 'v': 'name'}
# {'k': 'highway', 'v': 'residential'}
# id:
# 24568485
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'lanes', 'v': '3'}
# {'k': 'name', 'v': '休宁路'}
# {'k': 'name:en', 'v': 'Xiuning Road'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 24568502
# {'k': 'highway', 'v': 'primary'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'name', 'v': '临泉东路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 24568536
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'name', 'v': '金寨南路'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'ref', 'v': 'G206'}
# id:
# 24568539
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'lit', 'v': 'yes'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 24568543
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '宁国南路'}
# {'k': 'name:en', 'v': 'South Ningguo Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 24568551
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'name', 'v': '莲花路'}
# {'k': 'name:en', 'v': 'Lianhua Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 24568555
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '安庆路'}
# {'k': 'name:en', 'v': 'Anqing Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 24568569
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'lit', 'v': 'yes'}
# {'k': 'name', 'v': '和平路'}
# {'k': 'name:en', 'v': 'Heping Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 24783229
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '亳州路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 24783239
# {'k': 'highway', 'v': 'primary'}
# {'k': 'layer', 'v': '-1'}
# {'k': 'name', 'v': 'Qinxi East Road'}
# {'k': 'name:en', 'v': 'Qinxi East Road'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'tunnel', 'v': 'yes'}
# id:
# 25095216
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'layer', 'v': '1'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 25635945
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '紫蓬路'}
# id:
# 25635946
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '天都路'}
# {'k': 'name:en', 'v': 'Tiandu Rd.'}
# id:
# 37004152
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'lanes', 'v': '4'}
# {'k': 'layer', 'v': '1'}
# {'k': 'name', 'v': '长江西路'}
# {'k': 'name:en', 'v': 'West Changjiang Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'ref', 'v': 'G312'}
# id:
# 37004160
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 37004168
# {'k': 'highway', 'v': 'motorway'}
# id:
# 37004169
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 37004705
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 37004706
# {'k': 'highway', 'v': 'motorway'}
# id:
# 37004707
# {'k': 'highway', 'v': 'motorway'}
# id:
# 37004711
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 37004713
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 42244832
# {'k': 'highway', 'v': 'motorway'}
# id:
# 42245050
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 42245052
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 42245053
# {'k': 'highway', 'v': 'motorway'}
# id:
# 42245064
# {'k': 'highway', 'v': 'motorway'}
# id:
# 59167721
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 59167742
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 60211578
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'lit', 'v': 'yes'}
# {'k': 'name', 'v': '龙泉路'}
# {'k': 'name:en', 'v': 'Longquan Road'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 60211586
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary'}
# {'k': 'layer', 'v': '1'}
# {'k': 'name', 'v': '孝肃桥'}
# {'k': 'name:en', 'v': 'Xiaosu Bridge'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 60211599
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '大通路'}
# {'k': 'name:en', 'v': 'Datong Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 60211600
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'layer', 'v': '1'}
# {'k': 'name', 'v': '屯溪路桥'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 60211602
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary'}
# {'k': 'layer', 'v': '1'}
# {'k': 'name', 'v': '当涂路桥'}
# {'k': 'name:en', 'v': 'Dangtu Road'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 60211625
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '当涂路'}
# {'k': 'name:en', 'v': 'Dangtu Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 61310276
# {'k': 'highway', 'v': 'footway'}
# id:
# 61310278
# {'k': 'highway', 'v': 'footway'}
# id:
# 61310281
# {'k': 'highway', 'v': 'footway'}
# id:
# 61310284
# {'k': 'highway', 'v': 'footway'}
# id:
# 61310287
# {'k': 'highway', 'v': 'footway'}
# id:
# 61310288
# {'k': 'highway', 'v': 'footway'}
# id:
# 61310291
# {'k': 'highway', 'v': 'footway'}
# id:
# 61310292
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'footway'}
# id:
# 65174795
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary'}
# {'k': 'layer', 'v': '1'}
# {'k': 'ref', 'v': 'S331'}
# id:
# 65176037
# {'k': 'highway', 'v': 'motorway'}
# id:
# 65176048
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 65177027
# {'k': 'highway', 'v': 'motorway'}
# id:
# 65177762
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 65177810
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 65177878
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 65177880
# {'k': 'highway', 'v': 'motorway'}
# id:
# 65178055
# {'k': 'highway', 'v': 'motorway'}
# id:
# 75764018
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'source', 'v': 'bing'}
# id:
# 75764019
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 75764020
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 75764022
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 75764024
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 75764027
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 75764032
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 75764034
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 75764035
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 80255164
# {'k': 'highway', 'v': 'motorway'}
# id:
# 80255300
# {'k': 'highway', 'v': 'motorway'}
# id:
# 80255302
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 80255303
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 80256309
# {'k': 'highway', 'v': 'motorway'}
# id:
# 80256311
# {'k': 'highway', 'v': 'motorway'}
# id:
# 80261785
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'fixme', 'v': 'cross-check "chinese" offset'}
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'layer', 'v': '1'}
# {'k': 'ref', 'v': 'G312'}
# {'k': 'source', 'v': 'bing'}
# id:
# 80633193
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary'}
# {'k': 'layer', 'v': '1'}
# {'k': 'lit', 'v': 'yes'}
# {'k': 'name', 'v': '繁华大道'}
# {'k': 'name:en', 'v': 'Fan Hua Road'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 80636688
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 80636690
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 80636691
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 80636693
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 80637200
# {'k': 'highway', 'v': 'service'}
# id:
# 80637603
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 80637605
# {'k': 'highway', 'v': 'motorway'}
# id:
# 80637606
# {'k': 'foot', 'v': 'no'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 80638128
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary'}
# {'k': 'layer', 'v': '2'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 80638203
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 80638204
# {'k': 'highway', 'v': 'motorway'}
# id:
# 80638205
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 80638206
# {'k': 'highway', 'v': 'motorway'}
# id:
# 80638537
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 80638539
# {'k': 'highway', 'v': 'motorway'}
# id:
# 80638540
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 80638541
# {'k': 'highway', 'v': 'motorway'}
# id:
# 87306020
# {'k': 'fixme', 'v': 'name'}
# {'k': 'highway', 'v': 'residential'}
# id:
# 87474959
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'junction', 'v': 'roundabout'}
# {'k': 'name', 'v': '锦绣大道'}
# id:
# 87475929
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 87475930
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '石鼓路'}
# {'k': 'name:en', 'v': 'Shigu Rd.'}
# id:
# 87475934
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '石门路'}
# {'k': 'name:en', 'v': 'Shimen Rd.'}
# id:
# 87475936
# {'k': 'highway', 'v': 'tertiary'}
# id:
# 87487192
# {'k': 'highway', 'v': 'footway'}
# id:
# 87487193
# {'k': 'highway', 'v': 'footway'}
# id:
# 87487194
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '环翠路'}
# {'k': 'name:en', 'v': 'Huancui Rd.'}
# id:
# 87487195
# {'k': 'highway', 'v': 'footway'}
# id:
# 87487275
# {'k': 'highway', 'v': 'service'}
# id:
# 87487276
# {'k': 'highway', 'v': 'service'}
# id:
# 87487277
# {'k': 'highway', 'v': 'service'}
# id:
# 87487278
# {'k': 'highway', 'v': 'service'}
# id:
# 87487410
# {'k': 'highway', 'v': 'service'}
# id:
# 87487411
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 87487412
# {'k': 'highway', 'v': 'service'}
# id:
# 87487413
# {'k': 'highway', 'v': 'residential'}
# id:
# 87487414
# {'k': 'highway', 'v': 'service'}
# id:
# 87487415
# {'k': 'highway', 'v': 'service'}
# id:
# 87494435
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '白鸟路'}
# {'k': 'name:en', 'v': 'Bainiao Rd.'}
# id:
# 87494440
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 87494445
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '引针路'}
# {'k': 'name:en', 'v': 'Yingzhen Rd.'}
# id:
# 87494898
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 87494899
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 87494900
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 87494905
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 88779410
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '壶天路'}
# id:
# 88779411
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '仙人路'}
# id:
# 88779412
# {'k': 'highway', 'v': 'tertiary'}
# id:
# 88779413
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '石笋路'}
# {'k': 'surface', 'v': 'asphalt'}
# id:
# 88779414
# {'k': 'highway', 'v': 'tertiary'}
# id:
# 88779522
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '北海路'}
# {'k': 'name:en', 'v': 'Beihai Rd.'}
# id:
# 88779566
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '花园大道'}
# {'k': 'name:en', 'v': 'Huayuan Ave.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 88798985
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '佛掌路'}
# {'k': 'name:en', 'v': 'Fozhang Rd.'}
# id:
# 88799053
# {'k': 'highway', 'v': 'residential'}
# id:
# 88800462
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '丹霞路'}
# {'k': 'name:en', 'v': 'Danxia Rd.'}
# id:
# 88800463
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '耕耘路'}
# {'k': 'name:en', 'v': 'Gengyun Rd.'}
# id:
# 88800625
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '青龙潭路'}
# {'k': 'name:en', 'v': 'Qinglongtan Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 88800627
# {'k': 'highway', 'v': 'residential'}
# id:
# 88803734
# {'k': 'highway', 'v': 'primary'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'name', 'v': '祁门路'}
# {'k': 'name:en', 'v': 'Qimen Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 89380754
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '怀宁南路'}
# id:
# 89380755
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '徽毫路'}
# id:
# 89380756
# {'k': 'highway', 'v': 'residential'}
# id:
# 89380757
# {'k': 'highway', 'v': 'residential'}
# id:
# 89380758
# {'k': 'highway', 'v': 'residential'}
# id:
# 89380759
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 89380760
# {'k': 'highway', 'v': 'residential'}
# id:
# 89380761
# {'k': 'highway', 'v': 'residential'}
# id:
# 89380762
# {'k': 'highway', 'v': 'residential'}
# id:
# 89380794
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '叠嶂路'}
# {'k': 'name:en', 'v': 'Diezhang Rd.'}
# id:
# 89381349
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 89386486
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 89386487
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 89386488
# {'k': 'highway', 'v': 'residential'}
# id:
# 89386489
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 89386490
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 89386491
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 89386492
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 89386494
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 89386512
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '龙感湖路'}
# {'k': 'name:en', 'v': 'Longganhu Rd.'}
# id:
# 89386513
# {'k': 'highway', 'v': 'residential'}
# id:
# 89386514
# {'k': 'highway', 'v': 'residential'}
# id:
# 89387010
# {'k': 'highway', 'v': 'primary'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'name', 'v': '马鞍山路'}
# {'k': 'name:en', 'v': "Ma'anshan Rd."}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'ref', 'v': 'S351'}
# id:
# 89388172
# {'k': 'highway', 'v': 'primary_link'}
# {'k': 'name', 'v': '望江西路'}
# {'k': 'name:en', 'v': 'West Wangjiang Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 89388215
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '银杏路'}
# {'k': 'name:en', 'v': 'Yinxin Rd.'}
# id:
# 89388216
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '合欢路'}
# {'k': 'name:en', 'v': 'Hehuan Road'}
# id:
# 89388217
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'lanes', 'v': '4'}
# {'k': 'name', 'v': '红枫路'}
# {'k': 'name:en', 'v': 'Red Maple Rd.'}
# id:
# 89388279
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '天湖路'}
# {'k': 'name:en', 'v': 'Tianhu Rd.'}
# id:
# 89405691
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'int_name', 'v': 'Hei Tang Road;Jia Bei Tang'}
# {'k': 'name', 'v': '海棠路'}
# {'k': 'name:en', 'v': 'Haitang Rd.'}
# id:
# 89405692
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '金桂路'}
# {'k': 'name:en', 'v': 'Jingui Rd.'}
# id:
# 89405693
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'motorroad', 'v': 'yes'}
# {'k': 'name', 'v': '集贤路'}
# {'k': 'name:en', 'v': 'Jixian Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 89405831
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '长安路'}
# id:
# 89405832
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '翠竹路'}
# id:
# 89405833
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '樱花路'}
# id:
# 89405835
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '杭埠路'}
# {'k': 'name:en', 'v': 'Hangbu Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 89405927
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'int_name', 'v': 'Xiangzhang Avenue'}
# {'k': 'lanes', 'v': '3'}
# {'k': 'name', 'v': '铭传路'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'source', 'v': 'Yahoo'}
# id:
# 89405928
# {'k': 'highway', 'v': 'construction'}
# id:
# 89405929
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '天竹路'}
# id:
# 89405930
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '冬梅路'}
# id:
# 89405931
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '石楠路'}
# id:
# 89405932
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '秋菊路'}
# {'k': 'name:en', 'v': 'Qiuju Rd.'}
# id:
# 89416277
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '环翠路'}
# {'k': 'name:en', 'v': 'Huancui Rd.'}
# id:
# 89416280
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'layer', 'v': '1'}
# id:
# 89534783
# {'k': 'highway', 'v': 'residential'}
# id:
# 89534786
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '天鹅湖路'}
# {'k': 'name:en', 'v': "Tian'ehu Road"}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 89534787
# {'k': 'highway', 'v': 'residential'}
# id:
# 89534789
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '天波路'}
# id:
# 89534968
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '史河路'}
# {'k': 'name:en', 'v': 'Shihe Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 89635709
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '天鹅湖路'}
# {'k': 'name:en', 'v': "Tian'ehu Road"}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 89635710
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 89635748
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '石台路'}
# {'k': 'name:en', 'v': 'Shitai Road'}
# id:
# 89635749
# {'k': 'highway', 'v': 'residential'}
# id:
# 89635750
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '冬至路'}
# {'k': 'name:en', 'v': 'Dongzhi Road'}
# id:
# 89635751
# {'k': 'highway', 'v': 'residential'}
# id:
# 89635771
# {'k': 'highway', 'v': 'residential'}
# id:
# 89764456
# {'k': 'highway', 'v': 'residential'}
# id:
# 89764817
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '湖东路'}
# {'k': 'name:en', 'v': 'Hudong Road'}
# id:
# 89764818
# {'k': 'highway', 'v': 'residential'}
# id:
# 89764820
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 89764821
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '天鹅湖路'}
# {'k': 'name:en', 'v': "Tian'erhu Road"}
# id:
# 89905561
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '南京路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 89905562
# {'k': 'highway', 'v': 'residential'}
# id:
# 89905563
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '观海路'}
# id:
# 89905564
# {'k': 'highway', 'v': 'residential'}
# id:
# 89905565
# {'k': 'highway', 'v': 'residential'}
# id:
# 89905566
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '福州路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 89905567
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '庐州大道'}
# {'k': 'name:en', 'v': 'Luzhou Ave.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 89905568
# {'k': 'construction', 'v': 'yes'}
# {'k': 'highway', 'v': 'construction'}
# id:
# 89905569
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '万泉河路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 89905614
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '广西路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 89905615
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '洞庭湖路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 89905616
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '西藏路'}
# {'k': 'name:en', 'v': 'Tibet Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 89905618
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '林芝路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 89905619
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '长沙路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 89922672
# {'k': 'highway', 'v': 'primary'}
# {'k': 'lanes', 'v': '3'}
# {'k': 'name', 'v': '徽州大道'}
# {'k': 'name:en', 'v': 'Huizhou Ave,'}
# {'k': 'old_name', 'v': '南薰门街'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 89922673
# {'k': 'highway', 'v': 'tertiary'}
# id:
# 89922674
# {'k': 'highway', 'v': 'pedestrian'}
# id:
# 90928169
# {'k': 'highway', 'v': 'motorway'}
# id:
# 90953064
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '龙河路'}
# {'k': 'name:en', 'v': 'Longhe Rd.'}
# id:
# 90953123
# {'k': 'highway', 'v': 'residential'}
# id:
# 90953125
# {'k': 'fixme', 'v': 'name'}
# {'k': 'highway', 'v': 'residential'}
# id:
# 90953195
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '宁国路'}
# {'k': 'name:en', 'v': 'Ningguo Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 90953196
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '无为路'}
# {'k': 'name:en', 'v': 'Wuwei Road'}
# id:
# 90953197
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '宣城路'}
# {'k': 'name:en', 'v': 'Xuancheng Road'}
# id:
# 90955205
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': 'Qinxi East Road'}
# {'k': 'name:en', 'v': 'Qinxi East Road'}
# id:
# 90955206
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'layer', 'v': '1'}
# {'k': 'name', 'v': '水西门桥'}
# {'k': 'oneway', 'v': 'reversible'}
# id:
# 90955207
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '环城西路'}
# {'k': 'name:en', 'v': 'West Ring Road'}
# {'k': 'name:zh', 'v': '环城西路'}
# {'k': 'oneway', 'v': 'reversible'}
# id:
# 90955282
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 91172531
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '固镇路'}
# {'k': 'name:en', 'v': 'Guzhen Rd.'}
# id:
# 91172532
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '合瓦路'}
# {'k': 'name:en', 'v': 'Hewa Rd.'}
# id:
# 91172536
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '颖上路'}
# {'k': 'name:en', 'v': 'Yingshang Rd.'}
# id:
# 91172539
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '凤台路'}
# {'k': 'name:en', 'v': 'Fengtai Rd.'}
# id:
# 91172540
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '利辛路'}
# {'k': 'name:en', 'v': 'Lixin Rd.'}
# id:
# 91172543
# {'k': 'highway', 'v': 'residential'}
# id:
# 91996556
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '玉兰大道'}
# {'k': 'name:en', 'v': 'Yulan Ave.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 91996593
# {'k': 'highway', 'v': 'residential'}
# id:
# 91996612
# {'k': 'highway', 'v': 'residential'}
# id:
# 91996613
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 91996614
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '社岗路'}
# {'k': 'name:en', 'v': 'Shegang Rd.'}
# id:
# 91996617
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '高刘路'}
# {'k': 'name:en', 'v': 'Gaoliu Rd.'}
# id:
# 91996618
# {'k': 'highway', 'v': 'residential'}
# id:
# 91996724
# {'k': 'highway', 'v': 'primary_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 92000399
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '舒城路'}
# {'k': 'name:en', 'v': 'Shucheng Rd.'}
# id:
# 92353460
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 92353461
# {'k': 'highway', 'v': 'motorway'}
# id:
# 92353550
# {'k': 'highway', 'v': 'primary'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'name', 'v': '寿春路'}
# {'k': 'name:en', 'v': 'Shouchun Rd.'}
# {'k': 'old_name', 'v': '同春巷'}
# {'k': 'old_name_1', 'v': '柳木巷'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 92353551
# {'k': 'highway', 'v': 'primary'}
# {'k': 'layer', 'v': '-1'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'tunnel', 'v': 'yes'}
# id:
# 92353553
# {'k': 'highway', 'v': 'primary'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 92355588
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'lanes', 'v': '3'}
# {'k': 'layer', 'v': '-1'}
# {'k': 'name', 'v': '长江中路'}
# {'k': 'name:en', 'v': 'Mid Changjiang Rd.'}
# {'k': 'name:zh_pinyin', 'v': 'CHANGJIANG LU'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'ref', 'v': 'G312'}
# {'k': 'tunnel', 'v': 'yes'}
# id:
# 92355592
# {'k': 'highway', 'v': 'tertiary'}
# id:
# 92355593
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '定远路'}
# id:
# 92355595
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '夏园路'}
# {'k': 'name:en', 'v': 'Xiayuan Rd.'}
# id:
# 92356541
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '水阳江路'}
# {'k': 'name:en', 'v': 'Shuiyangjiang Road'}
# {'k': 'name:zh', 'v': '水阳江路'}
# {'k': 'name:zh_pinyin', 'v': 'Shuǐ Yáng Jiāng Lù'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 93173302
# {'k': 'highway', 'v': 'residential'}
# id:
# 93291677
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '河北路'}
# {'k': 'name:en', 'v': 'Hebei Rd.'}
# id:
# 93291686
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '青年路'}
# {'k': 'name:en', 'v': 'Qingnian Rd.'}
# {'k': 'name:zh', 'v': '青年路'}
# {'k': 'name:zh_pinyin', 'v': 'Qīngnián Lù'}
# id:
# 93291695
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '九华山路'}
# {'k': 'name:en', 'v': 'Jiuhuashan Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 93291696
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'layer', 'v': '-1'}
# {'k': 'name', 'v': 'Jiuhua Shanlu'}
# {'k': 'name:en', 'v': 'Jiuhua Shanlu'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'tunnel', 'v': 'yes'}
# id:
# 93411994
# {'k': 'highway', 'v': 'service'}
# id:
# 93545275
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '肥东路'}
# {'k': 'name:en', 'v': 'Feidong Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 93545276
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '瑯玡山路'}
# {'k': 'name:en', 'v': 'Langyashan Rd.'}
# id:
# 93545277
# {'k': 'highway', 'v': 'residential'}
# id:
# 93582256
# {'k': 'highway', 'v': 'primary'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 93582258
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93582259
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93582265
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93582271
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93582272
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93582273
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93582274
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93582275
# {'k': 'highway', 'v': 'primary_link'}
# id:
# 93582281
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93582286
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93582289
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93582290
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93582292
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93582293
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93582294
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93584073
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93584074
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93584076
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93584077
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93584078
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 93584079
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '烟墩路'}
# id:
# 93584080
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 93584081
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93584082
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93584083
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93584084
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93584085
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93584086
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93584087
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93584089
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93584090
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93584091
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93584092
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93584093
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93584095
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93584096
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93584097
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93584756
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93584758
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93584761
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93584762
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93584763
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93585945
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93585946
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93585947
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93585948
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93585949
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93585950
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93585951
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93585952
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93585953
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93585954
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93585956
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93585957
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93585958
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 93586642
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'name', 'v': '四里河路'}
# {'k': 'oneway', 'v': 'no'}
# {'k': 'ref', 'v': 'G206'}
# id:
# 93586644
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 93586646
# {'k': 'highway', 'v': 'primary_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 93678000
# {'k': 'highway', 'v': 'residential'}
# id:
# 94311312
# {'k': 'highway', 'v': 'residential'}
# id:
# 94311314
# {'k': 'highway', 'v': 'residential'}
# id:
# 94311317
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '金桔路'}
# id:
# 94313133
# {'k': 'highway', 'v': 'tertiary'}
# id:
# 94313135
# {'k': 'highway', 'v': 'unclassified'}
# id:
# 94313136
# {'k': 'highway', 'v': 'residential'}
# id:
# 95475024
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'service'}
# id:
# 95475028
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'service'}
# id:
# 95751733
# {'k': 'construction', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '新海大道'}
# {'k': 'name:en', 'v': 'Xinhai Ave.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 99917429
# {'k': 'highway', 'v': 'primary'}
# {'k': 'lanes', 'v': '3'}
# {'k': 'name', 'v': '新蚌埠路'}
# {'k': 'name:en', 'v': 'New Bengbu Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 99917480
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary'}
# {'k': 'lanes', 'v': '3'}
# {'k': 'layer', 'v': '1'}
# {'k': 'name', 'v': '新蚌埠路'}
# {'k': 'name:en', 'v': 'New Bengbu Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 99917512
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary'}
# {'k': 'layer', 'v': '1'}
# {'k': 'name', 'v': '新蚌埠路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 99917517
# {'k': 'highway', 'v': 'primary'}
# {'k': 'lanes', 'v': '3'}
# {'k': 'name', 'v': '新蚌埠路'}
# {'k': 'name:en', 'v': 'New Bengbu Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 105593541
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '天水路'}
# {'k': 'name:en', 'v': 'Tianshui Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 105695981
# {'k': 'highway', 'v': 'secondary'}
# id:
# 105695984
# {'k': 'highway', 'v': 'tertiary'}
# id:
# 105695994
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '烔栏路'}
# {'k': 'name:en', 'v': 'Tongyang-Langanji County Road'}
# {'k': 'ref', 'v': 'X100'}
# id:
# 105696009
# {'k': 'highway', 'v': 'secondary'}
# id:
# 107138265
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary'}
# {'k': 'int_name', 'v': 'Xi You Road'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'layer', 'v': '1'}
# {'k': 'name', 'v': '习友路'}
# {'k': 'name:en', 'v': 'Xiyou Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107138810
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'layer', 'v': '-1'}
# {'k': 'motorroad', 'v': 'yes'}
# {'k': 'name', 'v': '集贤路'}
# {'k': 'name:en', 'v': 'Jixian Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'tunnel', 'v': 'yes'}
# id:
# 107139073
# {'k': 'highway', 'v': 'motorway'}
# id:
# 107139074
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 107139075
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 107139076
# {'k': 'highway', 'v': 'motorway'}
# id:
# 107139213
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107139245
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'lanes', 'v': '4'}
# {'k': 'name', 'v': '集贤路'}
# {'k': 'name:en', 'v': 'Jixian Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107139246
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'layer', 'v': '-1'}
# {'k': 'name', 'v': '集贤路'}
# {'k': 'name:en', 'v': 'Jixian Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'tunnel', 'v': 'yes'}
# id:
# 107153237
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107153238
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107153239
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107153240
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'no'}
# id:
# 107153664
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107153665
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'no'}
# id:
# 107153666
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107153715
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107153716
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107153733
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '黄山路'}
# {'k': 'name:en', 'v': 'Huangshan Road'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107153734
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary'}
# {'k': 'layer', 'v': '1'}
# {'k': 'name', 'v': '黄山路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107155477
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107155478
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'no'}
# id:
# 107155479
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107155481
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107155482
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'no'}
# id:
# 107155484
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107155486
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107155487
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107183488
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107183490
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 107183491
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107183492
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 107183493
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107183494
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 107183495
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 107184733
# {'k': 'highway', 'v': 'motorway'}
# id:
# 107184735
# {'k': 'foot', 'v': 'no'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 107184740
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 107184743
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'foot', 'v': 'no'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 107184747
# {'k': 'foot', 'v': 'no'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 107184755
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 107185155
# {'k': 'highway', 'v': 'motorway'}
# id:
# 107185156
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 107185157
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 107185158
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'foot', 'v': 'no'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 107185160
# {'k': 'foot', 'v': 'no'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 107185164
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 107185295
# {'k': 'highway', 'v': 'motorway'}
# id:
# 107185296
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'foot', 'v': 'no'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 107185297
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'foot', 'v': 'no'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 107185298
# {'k': 'foot', 'v': 'no'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 107185299
# {'k': 'foot', 'v': 'no'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 107185300
# {'k': 'highway', 'v': 'motorway'}
# id:
# 107185301
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 107185302
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 107203319
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107203321
# {'k': 'bridge', 'v': 'viaduct'}
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'layer', 'v': '2'}
# {'k': 'name', 'v': '西一环路'}
# {'k': 'name:en', 'v': 'West Yihuan Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107203325
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'layer', 'v': '-1'}
# {'k': 'name', 'v': '梅山桥'}
# {'k': 'name:en', 'v': 'Meishan Bridge'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'tunnel', 'v': 'yes'}
# id:
# 107203326
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'name', 'v': '金寨路'}
# {'k': 'name:en', 'v': 'Jinzhai Rd.'}
# {'k': 'old_name', 'v': '德胜门大街'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'ref', 'v': 'G206'}
# id:
# 107203330
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'layer', 'v': '3'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107203332
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 107265389
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'name', 'v': '南一环路'}
# {'k': 'name:en', 'v': 'South Yihuan Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107265390
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'layer', 'v': '-1'}
# {'k': 'name', 'v': '梅山桥'}
# {'k': 'name:en', 'v': 'Meishan Bridge'}
# {'k': 'tunnel', 'v': 'yes'}
# id:
# 107266767
# {'k': 'bridge', 'v': 'viaduct'}
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'layer', 'v': '2'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107266768
# {'k': 'bridge', 'v': 'viaduct'}
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'layer', 'v': '2'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107266770
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'layer', 'v': '2'}
# {'k': 'name', 'v': '南一环路'}
# {'k': 'name:en', 'v': 'South Yihuan Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107267559
# {'k': 'bridge', 'v': 'viaduct'}
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'layer', 'v': '1'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107267560
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'layer', 'v': '1'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107268216
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'name', 'v': '长江西路'}
# {'k': 'name:en', 'v': 'West Changjiang Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'ref', 'v': 'S351'}
# id:
# 107378448
# {'k': 'highway', 'v': 'primary'}
# {'k': 'landuse', 'v': 'industrial'}
# {'k': 'name', 'v': '长宁大道'}
# {'k': 'name:en', 'v': 'Changning Ave.'}
# {'k': 'name:ja', 'v': '長寕大道'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107378449
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary'}
# {'k': 'layer', 'v': '1'}
# {'k': 'lit', 'v': 'yes'}
# {'k': 'name', 'v': '包公大道'}
# {'k': 'name:en', 'v': 'Baogong Ave.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107378452
# {'k': 'highway', 'v': 'primary'}
# {'k': 'lanes', 'v': '3'}
# {'k': 'name', 'v': '望江西路'}
# {'k': 'name:en', 'v': 'West Wangjiang Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107502887
# {'k': 'highway', 'v': 'primary'}
# {'k': 'int_name', 'v': 'Xi You Road'}
# {'k': 'lanes', 'v': '3'}
# {'k': 'name', 'v': '习友路'}
# {'k': 'name:en', 'v': 'Xiyou Road'}
# {'k': 'name:zh', 'v': '习友路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107502889
# {'k': 'highway', 'v': 'primary'}
# {'k': 'int_name', 'v': 'Xi You Road'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'name', 'v': '龙川路'}
# {'k': 'name:en', 'v': 'Longchuan Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 107502897
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'name', 'v': '金寨路'}
# {'k': 'name:en', 'v': 'Jinzhai Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'ref', 'v': 'G206'}
# {'k': 'surface', 'v': 'asphalt'}
# id:
# 107531357
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'layer', 'v': '1'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 112860987
# {'k': 'highway', 'v': 'residential'}
# id:
# 112860991
# {'k': 'highway', 'v': 'residential'}
# id:
# 112860996
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '呈坎路'}
# {'k': 'name:en', 'v': 'Chengkan Rd.'}
# id:
# 112860997
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'name', 'v': '望湖西路'}
# {'k': 'name:en', 'v': 'West Wanghu Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 112861000
# {'k': 'highway', 'v': 'residential'}
# id:
# 114279905
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'name', 'v': '金寨南路'}
# {'k': 'name:en', 'v': 'Jinzhai Road'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'ref', 'v': 'G206'}
# {'k': 'surface', 'v': 'asphalt'}
# id:
# 114279907
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary'}
# {'k': 'layer', 'v': '1'}
# {'k': 'lit', 'v': 'yes'}
# {'k': 'name', 'v': '繁华大道'}
# {'k': 'name:en', 'v': 'Fan Hua Road'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 114279916
# {'k': 'highway', 'v': 'primary'}
# {'k': 'lit', 'v': 'yes'}
# {'k': 'name', 'v': '繁华大道'}
# {'k': 'name:en', 'v': 'Fan Hua Road'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 114279920
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '徽州大道'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 114289530
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 114289532
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 114289536
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 114289537
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 114289538
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'no'}
# id:
# 114289543
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'layer', 'v': '1'}
# {'k': 'oneway', 'v': 'no'}
# id:
# 114291170
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'layer', 'v': '1'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 114995519
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'name', 'v': '南二环路'}
# {'k': 'name:en', 'v': 'South Erhuan Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 114995520
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '齐云山路'}
# {'k': 'name:en', 'v': 'Qiyun Road'}
# id:
# 114995524
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'name', 'v': '南二环路'}
# {'k': 'name:en', 'v': 'South Erhuan Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 114995532
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'layer', 'v': '-1'}
# {'k': 'name', 'v': '南二环路'}
# {'k': 'name:en', 'v': 'South Erhuan Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'tunnel', 'v': 'yes'}
# id:
# 115305434
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'layer', 'v': '-1'}
# {'k': 'name', 'v': '南二环路'}
# {'k': 'name:en', 'v': 'South Erhuan Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'tunnel', 'v': 'yes'}
# id:
# 115305436
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'name', 'v': '南二环路'}
# {'k': 'name:en', 'v': 'South Erhuan Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115306296
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'lanes', 'v': '3'}
# {'k': 'name', 'v': '潜山路'}
# {'k': 'name:en', 'v': 'Qianshan Road'}
# {'k': 'name:zh', 'v': '潜山路'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'ref', 'v': 'G206'}
# id:
# 115306523
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '佛子岭路'}
# id:
# 115306526
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '龙泉路'}
# {'k': 'name:en', 'v': 'Longquan Road'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115306527
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115306529
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115306879
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '天鹅湖路'}
# {'k': 'name:en', 'v': "Tian'ehu Rd."}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115306918
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '天鹅湖路'}
# {'k': 'name:en', 'v': "Tian'ehu Road"}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115307322
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': "Tian'erhu Lu"}
# {'k': 'name:en', 'v': "Tian'erhu Road"}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115307323
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': "Tian'erhu Lu"}
# {'k': 'name:en', 'v': "Tian'erhu Road"}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115316762
# {'k': 'highway', 'v': 'residential'}
# id:
# 115319497
# {'k': 'highway', 'v': 'service'}
# id:
# 115320031
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'name', 'v': '西二环路'}
# {'k': 'name:en', 'v': 'West Erhuan Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115320974
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '天鹅湖路'}
# {'k': 'name:en', 'v': "Tian'ehu Road"}
# {'k': 'name:zh', 'v': '天鹅湖路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115320975
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '天鹅湖路'}
# {'k': 'name:en', 'v': "Tian'ehu Road"}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115320977
# {'k': 'highway', 'v': 'residential'}
# id:
# 115325990
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'layer', 'v': '1'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115325994
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'name', 'v': '西二环路'}
# {'k': 'name:en', 'v': 'West 2nd Cir.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115325999
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'layer', 'v': '1'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115326002
# {'k': 'highway', 'v': 'primary_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115326588
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'layer', 'v': '1'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115326589
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'name', 'v': '西二环路'}
# {'k': 'name:en', 'v': 'West 2nd Cir.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115326590
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'name', 'v': '西二环路'}
# {'k': 'name:en', 'v': 'West Erhuan Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115326592
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'layer', 'v': '1'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115327271
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'name', 'v': '集贤路'}
# {'k': 'name:en', 'v': 'Jixian Rd.'}
# {'k': 'name:zh', 'v': '集贤路'}
# {'k': 'name:zh_pinyin', 'v': 'Jí Xián Lù'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115327273
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'name', 'v': '西二环路'}
# {'k': 'name:en', 'v': 'West Erhuan Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115327582
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115327583
# {'k': 'highway', 'v': 'service'}
# id:
# 115327584
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115328429
# {'k': 'highway', 'v': 'tertiary_link'}
# {'k': 'name', 'v': 'Hehuan Lu'}
# {'k': 'name:en', 'v': 'Hehuan Road'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115328430
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115328431
# {'k': 'highway', 'v': 'tertiary_link'}
# {'k': 'name', 'v': 'Hehuan Lu'}
# {'k': 'name:en', 'v': 'Hehuan Road'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115328432
# {'k': 'highway', 'v': 'tertiary_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115328433
# {'k': 'highway', 'v': 'tertiary_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115331105
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '翡翠路'}
# {'k': 'name:en', 'v': 'Feicui Road'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115331106
# {'k': 'highway', 'v': 'primary'}
# {'k': 'layer', 'v': '1'}
# {'k': 'name', 'v': '翡翠路'}
# {'k': 'name:en', 'v': 'Feicui Road'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115331108
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary'}
# {'k': 'layer', 'v': '1'}
# {'k': 'name', 'v': '翡翠路'}
# {'k': 'name:en', 'v': 'Feicui Road'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115372899
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'lanes', 'v': '3'}
# {'k': 'lit', 'v': 'yes'}
# {'k': 'name', 'v': '长江东路'}
# {'k': 'name:en', 'v': 'East Changjiang Rd'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'ref', 'v': 'G312'}
# {'k': 'source', 'v': 'GPS'}
# id:
# 115373444
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '撮镇路'}
# {'k': 'name:en', 'v': 'Cuozhen Rd'}
# id:
# 115373751
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 115373752
# {'k': 'highway', 'v': 'motorway'}
# id:
# 115373754
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 115373756
# {'k': 'highway', 'v': 'motorway'}
# id:
# 115374425
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'layer', 'v': '1'}
# {'k': 'lit', 'v': 'yes'}
# {'k': 'name', 'v': '长江东路'}
# {'k': 'name:en', 'v': 'East Changjiang Rd'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'ref', 'v': 'G312'}
# {'k': 'source', 'v': 'GPS'}
# id:
# 115374442
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'lanes', 'v': '3'}
# {'k': 'lit', 'v': 'yes'}
# {'k': 'name', 'v': '长江东路'}
# {'k': 'name:en', 'v': 'East Changjiang Rd'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'ref', 'v': 'G312'}
# {'k': 'source', 'v': 'GPS'}
# id:
# 115374885
# {'k': 'highway', 'v': 'motorway'}
# id:
# 115374886
# {'k': 'highway', 'v': 'motorway'}
# id:
# 115374887
# {'k': 'highway', 'v': 'motorway'}
# id:
# 115374888
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 115374889
# {'k': 'highway', 'v': 'motorway'}
# id:
# 115374890
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway'}
# id:
# 115375017
# {'k': 'highway', 'v': 'motorway'}
# id:
# 115375409
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '包公大道'}
# {'k': 'name:en', 'v': 'Baogong Ave.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115375540
# {'k': 'highway', 'v': 'primary'}
# {'k': 'lanes', 'v': '3'}
# {'k': 'name', 'v': '包公大道'}
# {'k': 'name:en', 'v': 'Baogong Ave.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115376044
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '岱河路'}
# {'k': 'name:en', 'v': 'Daihe Rd.'}
# id:
# 115376889
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '文忠路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115376892
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary'}
# {'k': 'layer', 'v': '1'}
# {'k': 'name', 'v': '文忠路'}
# {'k': 'name:en', 'v': 'Wenzhong Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115377767
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '学林路'}
# {'k': 'name:en', 'v': 'Xuelin Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115377768
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '学林路'}
# {'k': 'name:en', 'v': 'Xuelin Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 115379713
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'layer', 'v': '-1'}
# {'k': 'name', 'v': '包公大道'}
# {'k': 'name:en', 'v': 'Baogong Ave.'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'tunnel', 'v': 'yes'}
# id:
# 115379714
# {'k': 'highway', 'v': 'primary'}
# {'k': 'lanes', 'v': '3'}
# {'k': 'lit', 'v': 'yes'}
# {'k': 'name', 'v': '包公大道'}
# ...
# {'k': 'name:en', 'v': 'Jinzhai Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'ref', 'v': 'G206'}
# {'k': 'surface', 'v': 'asphalt'}
# id:
# 568043836
# {'k': 'bridge', 'v': 'viaduct'}
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'layer', 'v': '1'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 568043837
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'name', 'v': '金寨路'}
# {'k': 'name:en', 'v': 'Jinzhai Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'ref', 'v': 'G206'}
# {'k': 'surface', 'v': 'asphalt'}
# id:
# 568877566
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 568877567
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'name', 'v': '金寨路'}
# {'k': 'name:en', 'v': 'Jinzhai Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'ref', 'v': 'G206'}
# {'k': 'surface', 'v': 'asphalt'}
# id:
# 568877568
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'name', 'v': '金寨路'}
# {'k': 'name:en', 'v': 'Jinzhai Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'ref', 'v': 'G206'}
# {'k': 'surface', 'v': 'asphalt'}
# id:
# 568881782
# {'k': 'bridge', 'v': 'viaduct'}
# {'k': 'highway', 'v': 'trunk_link'}
# {'k': 'layer', 'v': '1'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 569127346
# {'k': 'highway', 'v': 'residential'}
# id:
# 569159031
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '马鞍山路'}
# {'k': 'name:en', 'v': "Ma'anshan Rd."}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 569236686
# {'k': 'bicycle', 'v': 'no'}
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'foot', 'v': 'no'}
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'horse', 'v': 'no'}
# {'k': 'lanes', 'v': '1'}
# {'k': 'layer', 'v': '1'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 569236687
# {'k': 'bicycle', 'v': 'no'}
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'foot', 'v': 'no'}
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'horse', 'v': 'no'}
# {'k': 'lanes', 'v': '1'}
# {'k': 'layer', 'v': '1'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 569498914
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '芜湖路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 569498915
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'lanes', 'v': '2'}
# {'k': 'name', 'v': '金寨路'}
# {'k': 'name:en', 'v': 'Jinzhai Rd.'}
# {'k': 'old_name', 'v': '德胜门大街'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'ref', 'v': 'G206'}
# {'k': 'surface', 'v': 'asphalt'}
# id:
# 569498916
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '芜湖路'}
# id:
# 569498917
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '芜湖路辅路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 569498918
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'name', 'v': '马鞍山路辅路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 569532448
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '望江东路辅路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 569532449
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '马鞍山路辅路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 569532450
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '马鞍山路辅路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 569576641
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '马鞍山路辅路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 569576642
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '马鞍山路辅路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 569737789
# {'k': 'highway', 'v': 'construction'}
# id:
# 569737791
# {'k': 'construction', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 569737792
# {'k': 'construction', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 569737793
# {'k': 'bridge', 'v': 'viaduct'}
# {'k': 'construction', 'v': 'yes'}
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'layer', 'v': '1'}
# {'k': 'name', 'v': '铜陵路高架'}
# {'k': 'name:en', 'v': 'Viaduct of Tongling Rd.'}
# {'k': 'oneway', 'v': '-1'}
# id:
# 569737794
# {'k': 'bridge', 'v': 'viaduct'}
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'layer', 'v': '1'}
# {'k': 'name', 'v': '铜陵路高架'}
# {'k': 'name:en', 'v': 'Viaduct of Tongling Rd.'}
# {'k': 'oneway', 'v': '-1'}
# id:
# 569809808
# {'k': 'construction', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary'}
# {'k': 'layer', 'v': '-1'}
# {'k': 'name', 'v': '少荃湖隧道'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'tunnel', 'v': 'yes'}
# id:
# 569809809
# {'k': 'construction', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary'}
# {'k': 'layer', 'v': '-1'}
# {'k': 'name', 'v': '少泉湖隧道'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'tunnel', 'v': 'yes'}
# id:
# 569825318
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '马鞍山路辅路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 569825319
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '马鞍山路辅路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 570877334
# {'k': 'highway', 'v': 'secondary'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 571544592
# {'k': 'highway', 'v': 'secondary'}
# id:
# 571544593
# {'k': 'highway', 'v': 'secondary'}
# id:
# 571570415
# {'k': 'highway', 'v': 'primary_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 571570416
# {'k': 'highway', 'v': 'primary_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 571591841
# {'k': 'highway', 'v': 'primary_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 571602934
# {'k': 'highway', 'v': 'primary_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 571836434
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '韶山路'}
# {'k': 'name:en', 'v': 'Shaoshan Rd.'}
# id:
# 571836435
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'layer', 'v': '1'}
# {'k': 'name', 'v': '韶山路'}
# {'k': 'name:en', 'v': 'Shaoshan Rd.'}
# id:
# 571836436
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary'}
# {'k': 'layer', 'v': '1'}
# {'k': 'name', 'v': '庐州大道'}
# {'k': 'name:en', 'v': 'Luzhou Ave,'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 571836437
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '庐州大道'}
# {'k': 'name:en', 'v': 'Luzhou Ave,'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 571836438
# {'k': 'highway', 'v': 'primary'}
# {'k': 'name', 'v': '庐州大道'}
# {'k': 'name:en', 'v': 'Luzhou Ave,'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 571836439
# {'k': 'bridge', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary'}
# {'k': 'layer', 'v': '1'}
# {'k': 'name', 'v': '庐州大道'}
# {'k': 'name:en', 'v': 'Luzhou Ave,'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 571836444
# {'k': 'highway', 'v': 'residential'}
# id:
# 571836446
# {'k': 'highway', 'v': 'residential'}
# id:
# 571836453
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '嵩山路'}
# id:
# 571848454
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '金炉路'}
# {'k': 'oneway', 'v': '-1'}
# id:
# 571848455
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '金炉路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 571848456
# {'k': 'highway', 'v': 'residential'}
# id:
# 571848457
# {'k': 'highway', 'v': 'residential'}
# id:
# 571848458
# {'k': 'highway', 'v': 'residential'}
# id:
# 571848459
# {'k': 'highway', 'v': 'residential'}
# id:
# 571848460
# {'k': 'highway', 'v': 'residential'}
# id:
# 571848461
# {'k': 'highway', 'v': 'residential'}
# id:
# 571848462
# {'k': 'highway', 'v': 'tertiary'}
# id:
# 571848463
# {'k': 'highway', 'v': 'residential'}
# id:
# 571848464
# {'k': 'highway', 'v': 'residential'}
# id:
# 571848465
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '松林路'}
# {'k': 'name:en', 'v': 'Songlin Rd.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 571848469
# {'k': 'highway', 'v': 'residential'}
# id:
# 571848474
# {'k': 'highway', 'v': 'residential'}
# id:
# 572497366
# {'k': 'highway', 'v': 'primary'}
# {'k': 'layer', 'v': '1'}
# {'k': 'name', 'v': '徽州大道'}
# {'k': 'name:en', 'v': 'Huizhou Ave.'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 572497367
# {'k': 'highway', 'v': 'primary'}
# {'k': 'layer', 'v': '1'}
# {'k': 'name', 'v': '徽州大道'}
# {'k': 'name:en', 'v': 'Huizhou Ave.'}
# {'k': 'oneway', 'v': '-1'}
# id:
# 573323621
# {'k': 'highway', 'v': 'residential'}
# id:
# 573323622
# {'k': 'highway', 'v': 'residential'}
# id:
# 573324460
# {'k': 'highway', 'v': 'residential'}
# id:
# 573325294
# {'k': 'highway', 'v': 'residential'}
# id:
# 573326774
# {'k': 'highway', 'v': 'residential'}
# id:
# 575705818
# {'k': 'construction', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 575705819
# {'k': 'construction', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 575705820
# {'k': 'construction', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 575705821
# {'k': 'construction', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 575705822
# {'k': 'construction', 'v': 'yes'}
# {'k': 'highway', 'v': 'primary'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 575705823
# {'k': 'construction', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 575705824
# {'k': 'construction', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 575705825
# {'k': 'construction', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 575705826
# {'k': 'construction', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 575705827
# {'k': 'construction', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 575705828
# {'k': 'construction', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 575705829
# {'k': 'construction', 'v': 'yes'}
# {'k': 'highway', 'v': 'motorway_link'}
# id:
# 576117431
# {'k': 'highway', 'v': 'primary_link'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 578652963
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'lanes', 'v': '4'}
# {'k': 'name', 'v': '长江西路'}
# {'k': 'name:en', 'v': 'West Changjiang Rd.'}
# {'k': 'old_name', 'v': '西平门大街'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'ref', 'v': 'G312'}
# id:
# 578652964
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '长江西路辅路'}
# {'k': 'oneway', 'v': 'yes'}
# id:
# 578652966
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'lanes', 'v': '4'}
# {'k': 'name', 'v': '长江中路'}
# {'k': 'name:en', 'v': 'Mid Changjiang Rd.'}
# {'k': 'name:zh_pinyin', 'v': 'CHANGJIANG LU'}
# {'k': 'old_name', 'v': '前大街'}
# {'k': 'oneway', 'v': '-1'}
# {'k': 'ref', 'v': 'G312'}
# id:
# 578652968
# {'k': 'highway', 'v': 'trunk'}
# {'k': 'lanes', 'v': '5'}
# {'k': 'name', 'v': '长江中路'}
# {'k': 'name:en', 'v': 'Mid Changjiang Rd.'}
# {'k': 'old_name', 'v': '西平门大街'}
# {'k': 'oneway', 'v': 'yes'}
# {'k': 'ref', 'v': 'G312'}
# id:
# 578652970
# {'k': 'highway', 'v': 'tertiary'}
# {'k': 'name', 'v': '长江中路辅路'}
# {'k': 'oneway', 'v': 'yes'}
# {'JAC大道',
#  '一环宁国路桥',
#  '一环马鞍山路桥',
#  '万佛山路',
#  '万佛湖路',
#  '万场路',
#  '万年埠路',
#  '万泉河路',
#  '万泽路',
#  '三国城路',
#  '三官塘西路',
#  '三河路',
#  '三角线桥',
#  '上海路',
#  '东一环裕溪路高架',
#  '东一环路',
#  '东二环路',
#  '东二环路高架',
#  '东方大道',
#  '东至路',
#  '东落客平台',
#  '东风大道',
#  '严刘路',
#  '中山路',
#  '中山路桥',
#  '中心街',
#  '中菜市路',
#  '临泉东路',
#  '临泉路',
#  '临泉路跨二十埠河桥',
#  '丹霞西路',
#  '丹霞路',
#  '丽水路',
#  '义和商业街',
#  '乐平路',
#  '乐水路',
#  '九华山路',
#  '九顶山路',
#  '九龙路',
#  '习友南路',
#  '习友路',
#  '书箱路',
#  '乳泉路',
#  '云南路',
#  '云海路',
#  '云谷路',
#  '五河路',
#  '井岗路',
#  '亳州路',
#  '亳州路桥',
#  '人民路',
#  '仙人路',
#  '仙霞路',
#  '仰桥路',
#  '休宁路',
#  '体育路',
#  '佛子岭路',
#  '佛掌南路',
#  '佛掌路',
#  '元店路',
#  '全椒路',
#  '全椒路（公交专用）',
#  '八公山路',
#  '公园路',
#  '公铁立交桥',
#  '六安路',
#  '六长路',
#  '兰州路',
#  '关井路',
#  '兴业大道',
#  '兴旺路',
#  '兴油路',
#  '兴港路',
#  '兴烔路',
#  '兴隆路',
#  '养正路',
#  '内蒙路',
#  '农兴路',
#  '农聚路',
#  '农贸路',
#  '冬梅路',
#  '冬至路',
#  '冯城街',
#  '凌云路',
#  '凤凰桥路',
#  '凤台路',
#  '凤台路桥',
#  '凤庆路',
#  '凤淮路',
#  '凤锦路',
#  '凤阳东路',
#  '凤霞路',
#  '凤麟路',
#  '出口：潜山路 习友路',
#  '出口：高速',
#  '创新大道',
#  '利辛路',
#  '前岭路',
#  '前江路',
#  '包公大道',
#  '包公路',
#  '包河大道',
#  '包河大道桥',
#  '包河大道高架',
#  '北一环四里河高架',
#  '北一环路',
#  '北二环路',
#  '北京路',
#  '北含山路',
#  '北城大道',
#  '北海路',
#  '北街',
#  '北部湾路',
#  '北雁湾路',
#  '匡河路',
#  '十五里河桥',
#  '半岛路',
#  '华一路',
#  '华三路',
#  '华二路',
#  '华南大道',
#  '华山路',
#  '华阳路',
#  '南一环路',
#  '南二环路',
#  '南京路',
#  '南北一号高架',
#  '南含山路',
#  '南大街',
#  '南宁东路',
#  '南宁西路',
#  '南屏路',
#  '南淝河大桥',
#  '南淝河路',
#  '南湾路',
#  '南薰门桥',
#  '南陵路',
#  '卧云路',
#  '卧龙路',
#  '卫星路',
#  '双凤路',
#  '双塘路',
#  '双墩路',
#  '双拥路',
#  '双水路',
#  '叠嶂路',
#  '叠翠峰路',
#  '古河路',
#  '台湾路',
#  '史河路',
#  '合作化南路',
#  '合作化南路高架桥',
#  '合作化路',
#  '合巢路',
#  '合掌路',
#  '合欢路',
#  '合水路',
#  '合瓦路',
#  '合白路',
#  '合相路',
#  '合蚌路',
#  '合钢桥',
#  '合马路',
#  '君山路',
#  '吴敬梓路',
#  '呈坎路',
#  '周谷堆路',
#  '和平路',
#  '和平路下穿桥',
#  '哈尔滨路',
#  '响洪甸路',
#  '唐杨路',
#  '唐疃路',
#  '嘉山路',
#  '嘉山路桥',
#  '嘉陵江路',
#  '四川路',
#  '四泉桥',
#  '四里河桥',
#  '四里河路',
#  '四里河路四里河高架',
#  '四顶山路',
#  '团结路',
#  '固镇路',
#  '国一路',
#  '国三路',
#  '国二路',
#  '国际大道',
#  '土山路',
#  '圩新路',
#  '城东湖路',
#  '城西湖路',
#  '塘西河桥',
#  '壶天路',
#  '复兴路',
#  '夏园路',
#  '大众路',
#  '大创路',
#  '大别山路',
#  '大强路',
#  '大禹路',
#  '大联圩路',
#  '大连路',
#  '大通路',
#  '大郭路',
#  '大龙山路',
#  '天乐路',
#  '天山路',
#  '天智路',
#  '天柱山大道',
#  '天柱路',
#  '天水路',
#  '天河路',
#  '天波路',
#  '天津路',
#  '天海路',
#  '天湖路',
#  '天竹路',
#  '天达路',
#  '天通路',
#  '天都路',
#  '天鹅湖路',
#  '天龙路',
#  '太原路',
#  '太和路',
#  '太子山路',
#  '太湖路',
#  '奎河路',
#  '始信路',
#  '姚王路',
#  '姜家湖路',
#  '孔雀台路',
#  '孝肃桥',
#  '学府路',
#  '学林路',
#  '宁国南路',
#  '宁国路',
#  '宁夏路',
#  '宁西路',
#  '安乐路',
#  '安兴路',
#  '安凯路',
#  '安庆路',
#  '安盛路',
#  '宋斗湾桥',
#  '宋斗湾路',
#  '宏图大道',
#  '宏村路',
#  '官亭路',
#  '定远路',
#  '宣城路',
#  '宣城路桥',
#  '宿州路',
#  '宿松路',
#  '富康路',
#  '寿春东路',
#  '寿春路',
#  '寿春路桥',
#  '将军岭路',
#  '小蜀山路',
#  '少泉湖隧道',
#  '少荃湖隧道',
#  '少荃街',
#  '屏山路',
#  '屯溪路桥',
#  '山东路',
#  '山湖路',
#  '岱河路',
#  '岳西路',
#  '嵩山路',
#  '巢湖南路',
#  '巢湖路',
#  '幸福路',
#  '广德路',
#  '广西路',
#  '广西路桥',
#  '庐州大道',
#  '庐州大道桥',
#  '庐江路',
#  '店费路',
#  '康乐路',
#  '延乔路',
#  '延安路',
#  '建安大道',
#  '建设路',
#  '引针路',
#  '当涂北路',
#  '当涂路',
#  '当涂路桥',
#  '彩虹路',
#  '徽中路',
#  '徽华路',
#  '徽富路',
#  '徽州大道',
#  '徽州大道桥',
#  '徽州大道辅道',
#  '徽州大道高架',
#  '徽强路',
#  '徽毫路',
#  '怀宁南路',
#  '怀宁路',
#  '怀远路',
#  '恒大路',
#  '恒山路',
#  '成都路',
#  '扬子江路',
#  '扶疏路',
#  '护城路',
#  '拱辰门桥',
#  '指南路',
#  '振兴路',
#  '撮镇路',
#  '支河路',
#  '敬亭山路',
#  '文山路',
#  '文忠路',
#  '文曲路',
#  '新华街',
#  '新大街',
#  '新安江路',
#  '新安江路桥',
#  '新民路',
#  '新汴河路',
#  '新海大道',
#  '新蚌埠路',
#  '新街',
#  '方兴大道',
#  '方兴湖隧道',
#  '无为路',
#  '旺兴街',
#  '昌盛路',
#  '昌都路',
#  '明光路',
#  '明光路桥',
#  '明珠大道',
#  '明皇路',
#  '明皇路桥',
#  '星光大道',
#  '星光西路',
#  '曙光桥',
#  '曹冲路',
#  '曹营街',
#  '月亮湾路',
#  '望江东路',
#  '望江东路辅路',
#  '望江西路',
#  '望湖西路',
#  '朝阳路',
#  '机场便道',
#  '机场高速',
#  '李六路',
#  '来安路',
#  '杨井路',
#  '杨林路',
#  '杭埠河大道',
#  '杭埠路',
#  '杭州路',
#  '松林路',
#  '松荫桥',
#  '板桥河沿河路',
#  '林湖路',
#  '林芝路',
#  '枞阳路',
#  '枫林路',
#  '柳孜路',
#  '柳荫塘路',
#  '栏滨路',
#  '栏滨路上跨合芜高速大桥',
#  '桂王路',
#  '桃园路',
#  '桃枝路',
#  '桐城南路',
#  '桐城路',
#  '桐城路桥',
#  '桥头集路',
#  '桥湾路',
#  '梁古大街',
#  '梁园路',
#  '梅冲湖路',
#  '梅山桥',
#  '梅山路',
#  '梦溪路',
#  '梳背桥',
#  '棋石路',
#  '森林大道',
#  '樊洼路',
#  '横大路',
#  '樱花路',
#  '檀香路',
#  '歙县路',
#  '正阳路',
#  '武汉路',
#  '武里山路',
#  '毕昇路',
#  '民族团结路',
#  '水东路',
#  '水西门桥',
#  '水阳江路',
#  '永和路',
#  '永红路',
#  '永青大桥',
#  '汕头路',
#  '江淮路',
#  '江苏路',
#  '汤口路',
#  '汲桥路',
#  '汶水路',
#  '沁源路',
#  '沈东路',
#  '沈阳路',
#  '河东路',
#  '河北路',
#  '河南路',
#  '沿河东路',
#  '沿河西路',
#  '沿河西路桥',
#  '沿河路',
#  '泉阳路',
#  '泗州路',
#  '泗水路',
#  '洞庭湖桥',
#  '洞庭湖路',
#  '洪河路',
#  '派河大桥',
#  '派河大道',
#  '浍水路',
#  '济河路',
#  '浙江路',
#  '浮山路',
#  '浮槎山路',
#  '浮莲路',
#  '海关路',
#  '海南路',
#  '海棠路',
#  '涂山路',
#  '涡阳路',
#  '润河路',
#  '淝河路',
#  '淠河路',
#  '淮北路',
#  '淮南路',
#  '淮河西路',
#  '淮河路',
#  '淮河路桥',
#  '淮海大道',
#  '深圳路',
#  '清泉路',
#  '清源路',
#  '清源路桥',
#  '清溪路',
#  '清潭路',
#  '温合线',
#  '湖东路',
#  '湖光路',
#  '湖北路',
#  '湖南路',
#  '滁州路',
#  '滨河路',
#  '潜口路',
#  '潜山路',
#  '潜山路立交',
#  '潜水西路',
#  '潭冲路',
#  '澳门路',
#  '濛河路',
#  '火龙地路',
#  '灵壁路',
#  '灵石路',
#  '炯炀河桥',
#  '烈山路',
#  '烔中路',
#  '烔栏路',
#  '烔炀路',
#  '烔黄路',
#  '烟墩路',
#  '烟汕线',
#  '煤场路',
#  '燎原路',
#  '燕子河路',
#  '玉兰大道',
#  '玉屏路',
#  '玉带桥',
#  '玉皇山路',
#  '玉石山路',
#  '玉龙路',
#  '玉龙路桥',
#  '王步文路',
#  '环圩东路',
#  '环圩西路',
#  '环城东路',
#  '环城南路',
#  '环城西路',
#  '环巢湖大道',
#  '环湖北路',
#  '环湖北路观光车道',
#  '环翠路',
#  '珍珠路',
#  '珠江路',
#  '琥珀桥',
#  '瑞丰路',
#  '瑯玡山路',
#  '甘泉路',
#  '田埠西路',
#  '界首路',
#  '疏影路',
#  '白鸟路',
#  '百草街',
#  '皇嘉路',
#  '皇藏峪路',
#  '皖水路',
#  '皖河路',
#  '相城路',
#  '相山路',
#  '省人大 芜湖路出口',
#  '省道105',
#  '石台路',
#  '石塘路',
#  '石柱路',
#  '石楠路',
#  '石笋路',
#  '石莲北路',
#  '石莲南路',
#  '石长路',
#  '石门路',
#  '石鼓路',
#  '磨余路',
#  '磨子潭路',
#  '磨店街',
#  '磨黄路',
#  '社岗路',
#  '祁门路',
#  '神龙路',
#  '祥和路',
#  '福山路',
#  '福州路',
#  '秋菊路',
#  '科学大道',
#  '科学岛路',
#  '科技园路',
#  '程长庚路',
#  '稻香路',
#  '空港南路',
#  '站东路',
#  '站前东路',
#  '站前支路',
#  '站前路',
#  '站塘路',
#  '站西路',
#  '章华台路',
#  '粮站路',
#  '紫云路',
#  '紫云路桥',
#  '紫石路',
#  '紫蓬路',
#  '繁华大道',
#  '繁华大道大桥',
#  '红星路',
#  '红枫路',
#  '纪念广场下穿',
#  '绩溪路',
#  '翠竹路',
#  '翡翠桥',
#  '翡翠路',
#  '耀远路',
#  '老淮南线桥',
#  '老街',
#  '耕耘路',
#  '聚星桥',
#  '肥东路',
#  '肥西路',
#  '肥西路桥',
#  '育才路',
#  '胜利路',
#  '胜利路桥',
#  '胜利路立交桥',
#  '舒城路',
#  '芙蓉路',
#  '芜湖路',
#  '芜湖路辅路',
#  '芦岭路',
#  '芦花路',
#  '花园大道',
#  '花园街',
#  '苏岗路',
#  '苏柳路',
#  '茂林路',
#  '茨河路',
#  '荆山路',
#  '荷塘路',
#  '荷花塘路',
#  '荷花路',
#  '莲花路',
#  '菩提大道',
#  '菱湖路',
#  '落客平台',
#  '葡萄园路',
#  '董铺路',
#  '蒙城北路',
#  '蒙城路',
#  '蒙河路',
#  '蓬莱路',
#  '虹桥',
#  '蜀山东路',
#  '蜀峰路',
#  '衡山路',
#  '袁大路',
#  '裕丰路',
#  '裕溪路',
#  '裕溪路桥',
#  '裕溪路高架',
#  '襄河路',
#  '襄河路桥',
#  '西一环四里河高架',
#  '西一环路',
#  '西二环',
#  '西二环路',
#  '西园西路',
#  '西大路',
#  '西宁路',
#  '西安路',
#  '西山驿路',
#  '西淝河路',
#  '西落客平台',
#  '西藏路',
#  '西递路',
#  '观海路',
#  '谷河路',
#  '贵州路',
#  '贵池路',
#  '贵阳路',
#  '迎宾路',
#  '迎春路',
#  '迎松路',
#  '迎淮路',
#  '连水路',
#  '通宝路',
#  '通淮中路',
#  '通达路',
#  '遵义路',
#  '邓稼先路',
#  '郎溪路',
#  '采石路',
#  '重庆路',
#  '金兰路',
#  '金宁路',
#  '金安路',
#  '金富路',
#  '金寨南路',
#  '金寨南路辅道',
#  '金寨路',
#  '金寨路高架桥',
#  '金岗大道',
#  '金峰路',
#  '金斗东路',
#  '金斗北路',
#  '金斗西路',
#  '金桂路',
#  '金桔路',
#  '金梅路',
#  '金江路',
#  '金池路',
#  '金海路',
#  '金炉路',
#  '金珠路',
#  '金蓉路',
#  '金阁路',
#  '金阳路',
#  '钟油坊路',
#  '铁笛路',
#  '铜陵北路',
#  '铜陵路',
#  '铜陵路桥',
#  '铜陵路高架',
#  '铭传路',
#  '银杏大道',
#  '银杏路',
#  '锦绣大道',
#  '长丰路',
#  '长丰路桥',
#  '长临路',
#  '长乐路',
#  '长宁大道',
#  '长安路',
#  '长岗路',
#  '长春街',
#  '长松路',
#  '长江东大街',
#  '长江东大街桥',
#  '长江东路',
#  '长江东路桥',
#  '长江东路辅路',
#  '长江中路',
#  '长江中路辅路',
#  '长江西路',
#  '长江西路辅路',
#  '长江西路高架桥',
#  '长江路桥',
#  '长沙路',
#  '长沙路桥',
#  '长白山路',
#  '阊水路',
#  '阐河路',
#  '阜南路',
#  '阜阳北路',
#  '阜阳北路高架',
#  '阜阳北路高架桥',
#  '阜阳路',
#  '阜阳路桥',
#  '陵园路',
#  '障山路',
#  '集贤路',
#  '雨山路',
#  '雪霁北路',
#  '雪霁路',
#  '霍山路',
#  '霍邱路',
#  '青年北路',
#  '青年路',
#  '青翠路',
#  '青阳路',
#  '青鸾路',
#  '青龙大道',
#  '青龙潭路',
#  '青龙路',
#  '靶场路',
#  '韶山路',
#  '项王东路',
#  '颍河路',
#  '颖上路',
#  '馆驿路',
#  '香店路',
#  '香怡路',
#  '香樟大道',
#  '香港路',
#  '香蒲路',
#  '马家渡大桥',
#  '马鞍山路',
#  '马鞍山路辅路',
#  '高刘路',
#  '高架入口',
#  '高王桥',
#  '高铁路',
#  '魏武大道',
#  '鸡裕河桥',
#  '鹿鸣山路',
#  '黄山路',
#  '黄河路',
#  '齐云山路',
#  '龙兴大道',
#  '龙图路',
#  '龙子湖路',
#  '龙岗路',
#  '龙岗路桥',
#  '龙川路',
#  '龙感湖路',
#  '龙河口路',
#  '龙河路',
#  '龙泉大街',
#  '龙泉路',
#  '龙湖路',
#  '龙潭桥',
#  '龙灯路',
#  '龙脊山路',
#  '龙蟠路',
#  '龙门岭路'}

# %%
print(len(roadNameSet))
# Out:
# 765

# %%
# 根据路名获取路网中道路相关的路段wayid,构建道路表
def constructRoadTable(tree, roadNameSet):
    roadDataFrame = pd.DataFrame(columns=['roadName', 'wayID', 'roadType', 'user', 'timestamp', 'version'])
    roadInfo = defaultdict(lambda: 0)
    roadType = ''
    roadNum=1
    for roadName in roadNameSet:
        print('正在处理第{}条路： {}'.format(roadNum,roadName))
        roadNum+=1
        for elem in tree.iter(tag='way'):
            tag_k = elem.findall('tag')
            for tag in tag_k:
                if (tag.attrib['k'] == 'highway'):
                    roadType = tag.attrib['v']
                if (tag.attrib['k'] == 'name'):
                    if (tag.attrib['v'] == roadName):
                        roadInfo['roadName'] = roadName
                        roadInfo['wayID'] = elem.attrib['id']
                        roadInfo['roadType'] = roadType
                        roadInfo['user'] = elem.attrib['user']
                        roadInfo['timestamp'] = elem.attrib['timestamp']
                        roadInfo['version'] = elem.attrib['version']
                        tempDF = pd.DataFrame([roadInfo])
                        roadDataFrame = pd.concat([roadDataFrame, tempDF], ignore_index=True)
    print('处理了{}条路'.format(roadNum))
    return roadDataFrame

# %%
df=constructRoadTable(tree, roadNameSet)
# Out:
# 正在处理第1条路： 青龙潭路
# 正在处理第2条路： 徽富路
# 正在处理第3条路： 凤阳东路
# 正在处理第4条路： 胜利路
# 正在处理第5条路： 丽水路
# 正在处理第6条路： 石莲北路
# 正在处理第7条路： 河北路
# 正在处理第8条路： 河东路
# 正在处理第9条路： 东至路
# 正在处理第10条路： 玉皇山路
# 正在处理第11条路： 五河路
# 正在处理第12条路： 遵义路
# 正在处理第13条路： 派河大道
# 正在处理第14条路： 龙泉路
# 正在处理第15条路： 荆山路
# 正在处理第16条路： 大联圩路
# 正在处理第17条路： 龙岗路
# 正在处理第18条路： 一环宁国路桥
# 正在处理第19条路： 阐河路
# 正在处理第20条路： 磨余路
# 正在处理第21条路： 石莲南路
# 正在处理第22条路： 天河路
# 正在处理第23条路： 杭埠河大道
# 正在处理第24条路： 乳泉路
# 正在处理第25条路： 樱花路
# 正在处理第26条路： 华一路
# 正在处理第27条路： 西山驿路
# 正在处理第28条路： 鸡裕河桥
# 正在处理第29条路： 苏岗路
# 正在处理第30条路： 观海路
# 正在处理第31条路： 烟墩路
# 正在处理第32条路： 三国城路
# 正在处理第33条路： 玉石山路
# 正在处理第34条路： 仙霞路
# 正在处理第35条路： 金斗东路
# 正在处理第36条路： 障山路
# 正在处理第37条路： 安凯路
# 正在处理第38条路： 沈阳路
# 正在处理第39条路： 湖北路
# 正在处理第40条路： 清潭路
# 正在处理第41条路： 森林大道
# 正在处理第42条路： 昌都路
# 正在处理第43条路： 天波路
# 正在处理第44条路： 西二环路
# 正在处理第45条路： 金梅路
# 正在处理第46条路： 烟汕线
# 正在处理第47条路： 雪霁北路
# 正在处理第48条路： 茂林路
# 正在处理第49条路： 蒙城北路
# 正在处理第50条路： 枫林路
# 正在处理第51条路： 天湖路
# 正在处理第52条路： 四里河桥
# 正在处理第53条路： 唐杨路
# 正在处理第54条路： 燕子河路
# 正在处理第55条路： 兴港路
# 正在处理第56条路： 阜阳北路高架桥
# 正在处理第57条路： 唐疃路
# 正在处理第58条路： 永青大桥
# 正在处理第59条路： 新民路
# 正在处理第60条路： 冬梅路
# 正在处理第61条路： 南薰门桥
# 正在处理第62条路： 农贸路
# 正在处理第63条路： 匡河路
# 正在处理第64条路： 铜陵路
# 正在处理第65条路： 老淮南线桥
# 正在处理第66条路： 台湾路
# 正在处理第67条路： 永红路
# 正在处理第68条路： 天智路
# 正在处理第69条路： 皖河路
# 正在处理第70条路： 襄河路桥
# 正在处理第71条路： 琥珀桥
# 正在处理第72条路： 梁园路
# 正在处理第73条路： 三河路
# 正在处理第74条路： 柳孜路
# 正在处理第75条路： 当涂路桥
# 正在处理第76条路： 站前路
# 正在处理第77条路： 凌云路
# 正在处理第78条路： 包公路
# 正在处理第79条路： 疏影路
# 正在处理第80条路： 方兴大道
# 正在处理第81条路： 全椒路
# 正在处理第82条路： 淮河路桥
# 正在处理第83条路： 当涂路
# 正在处理第84条路： 重庆路
# 正在处理第85条路： 大禹路
# 正在处理第86条路： 石鼓路
# 正在处理第87条路： 珍珠路
# 正在处理第88条路： 章华台路
# 正在处理第89条路： 紫蓬路
# 正在处理第90条路： 烔栏路
# 正在处理第91条路： 白鸟路
# 正在处理第92条路： 海棠路
# 正在处理第93条路： 广德路
# 正在处理第94条路： 玉兰大道
# 正在处理第95条路： 耕耘路
# 正在处理第96条路： 皇藏峪路
# 正在处理第97条路： 泉阳路
# 正在处理第98条路： 西一环四里河高架
# 正在处理第99条路： 祁门路
# 正在处理第100条路： 佛掌路
# 正在处理第101条路： 桐城路桥
# 正在处理第102条路： 阜阳北路高架
# 正在处理第103条路： 护城路
# 正在处理第104条路： 鹿鸣山路
# 正在处理第105条路： 滨河路
# 正在处理第106条路： 华山路
# 正在处理第107条路： 靶场路
# 正在处理第108条路： 西大路
# 正在处理第109条路： 三官塘西路
# 正在处理第110条路： 贵阳路
# 正在处理第111条路： 望湖西路
# 正在处理第112条路： 荷花塘路
# 正在处理第113条路： 迎春路
# 正在处理第114条路： 天水路
# 正在处理第115条路： 孔雀台路
# 正在处理第116条路： 霍邱路
# 正在处理第117条路： 云南路
# 正在处理第118条路： 富康路
# 正在处理第119条路： 百草街
# 正在处理第120条路： 北部湾路
# 正在处理第121条路： 古河路
# 正在处理第122条路： 泗水路
# 正在处理第123条路： 文曲路
# 正在处理第124条路： 四泉桥
# 正在处理第125条路： 洞庭湖桥
# 正在处理第126条路： 兴油路
# 正在处理第127条路： 浮山路
# 正在处理第128条路： 兴隆路
# 正在处理第129条路： 天津路
# 正在处理第130条路： 淮北路
# 正在处理第131条路： 一环马鞍山路桥
# 正在处理第132条路： 曹冲路
# 正在处理第133条路： 颖上路
# 正在处理第134条路： 桥头集路
# 正在处理第135条路： 纪念广场下穿
# 正在处理第136条路： 魏武大道
# 正在处理第137条路： 龙河口路
# 正在处理第138条路： 将军岭路
# 正在处理第139条路： 休宁路
# 正在处理第140条路： 恒大路
# 正在处理第141条路： 桐城路
# 正在处理第142条路： 关井路
# 正在处理第143条路： 井岗路
# 正在处理第144条路： 龙兴大道
# 正在处理第145条路： 梅冲湖路
# 正在处理第146条路： 书箱路
# 正在处理第147条路： 宁夏路
# 正在处理第148条路： 小蜀山路
# 正在处理第149条路： 长江东大街
# 正在处理第150条路： 韶山路
# 正在处理第151条路： 汲桥路
# 正在处理第152条路： 淠河路
# 正在处理第153条路： 邓稼先路
# 正在处理第154条路： 芙蓉路
# 正在处理第155条路： 双拥路
# 正在处理第156条路： 桥湾路
# 正在处理第157条路： 红枫路
# 正在处理第158条路： 卧龙路
# 正在处理第159条路： 泗州路
# 正在处理第160条路： 长岗路
# 正在处理第161条路： 齐云山路
# 正在处理第162条路： 大连路
# 正在处理第163条路： 环圩东路
# 正在处理第164条路： 长江西路辅路
# 正在处理第165条路： 浍水路
# 正在处理第166条路： 农兴路
# 正在处理第167条路： 华二路
# 正在处理第168条路： 农聚路
# 正在处理第169条路： 裕溪路高架
# 正在处理第170条路： 潜山路立交
# 正在处理第171条路： 朝阳路
# 正在处理第172条路： 吴敬梓路
# 正在处理第173条路： 淮南路
# 正在处理第174条路： 郎溪路
# 正在处理第175条路： 东落客平台
# 正在处理第176条路： 清泉路
# 正在处理第177条路： 北城大道
# 正在处理第178条路： 九顶山路
# 正在处理第179条路： 金寨路高架桥
# 正在处理第180条路： 卫星路
# 正在处理第181条路： 秋菊路
# 正在处理第182条路： 明光路
# 正在处理第183条路： 滁州路
# 正在处理第184条路： 六长路
# 正在处理第185条路： 沿河路
# 正在处理第186条路： 宏村路
# 正在处理第187条路： 恒山路
# 正在处理第188条路： 新华街
# 正在处理第189条路： 来安路
# 正在处理第190条路： 学林路
# 正在处理第191条路： 洪河路
# 正在处理第192条路： 柳荫塘路
# 正在处理第193条路： 梳背桥
# 正在处理第194条路： 中菜市路
# 正在处理第195条路： 香港路
# 正在处理第196条路： 南北一号高架
# 正在处理第197条路： 龙脊山路
# 正在处理第198条路： 塘西河桥
# 正在处理第199条路： 西递路
# 正在处理第200条路： 阜阳路桥
# 正在处理第201条路： 石门路
# 正在处理第202条路： 南淝河路
# 正在处理第203条路： 大通路
# 正在处理第204条路： 大强路
# 正在处理第205条路： 山湖路
# 正在处理第206条路： 合相路
# 正在处理第207条路： 杭埠路
# 正在处理第208条路： 石塘路
# 正在处理第209条路： 东一环路
# 正在处理第210条路： 长丰路
# 正在处理第211条路： 界首路
# 正在处理第212条路： 南大街
# 正在处理第213条路： 指南路
# 正在处理第214条路： 高架入口
# 正在处理第215条路： 九华山路
# 正在处理第216条路： 合欢路
# 正在处理第217条路： 金桔路
# 正在处理第218条路： 安兴路
# 正在处理第219条路： 水东路
# 正在处理第220条路： 香店路
# 正在处理第221条路： 北京路
# 正在处理第222条路： 涡阳路
# 正在处理第223条路： 当涂北路
# 正在处理第224条路： 金斗西路
# 正在处理第225条路： 胜利路桥
# 正在处理第226条路： 马鞍山路辅路
# 正在处理第227条路： 凤台路桥
# 正在处理第228条路： 曙光桥
# 正在处理第229条路： 金海路
# 正在处理第230条路： 耀远路
# 正在处理第231条路： 建安大道
# 正在处理第232条路： 天乐路
# 正在处理第233条路： 金阁路
# 正在处理第234条路： 杭州路
# 正在处理第235条路： 公铁立交桥
# 正在处理第236条路： 潭冲路
# 正在处理第237条路： 李六路
# 正在处理第238条路： 金斗北路
# 正在处理第239条路： 青龙大道
# 正在处理第240条路： 站前支路
# 正在处理第241条路： 环圩西路
# 正在处理第242条路： 国一路
# 正在处理第243条路： 姚王路
# 正在处理第244条路： 东一环裕溪路高架
# 正在处理第245条路： 临泉东路
# 正在处理第246条路： 林芝路
# 正在处理第247条路： 和平路
# 正在处理第248条路： 蜀峰路
# 正在处理第249条路： 玉龙路桥
# 正在处理第250条路： 民族团结路
# 正在处理第251条路： 江淮路
# 正在处理第252条路： 周谷堆路
# 正在处理第253条路： 清源路
# 正在处理第254条路： 通宝路
# 正在处理第255条路： 太和路
# 正在处理第256条路： 梅山路
# 正在处理第257条路： 广西路桥
# 正在处理第258条路： 葡萄园路
# 正在处理第259条路： 九龙路
# 正在处理第260条路： 烈山路
# 正在处理第261条路： 煤场路
# 正在处理第262条路： 仰桥路
# 正在处理第263条路： 燎原路
# 正在处理第264条路： 湖光路
# 正在处理第265条路： 包河大道
# 正在处理第266条路： 石长路
# 正在处理第267条路： 长临路
# 正在处理第268条路： 桃园路
# 正在处理第269条路： 西二环
# 正在处理第270条路： 新大街
# 正在处理第271条路： 铜陵路桥
# 正在处理第272条路： 长江东路辅路
# 正在处理第273条路： 万场路
# 正在处理第274条路： 苏柳路
# 正在处理第275条路： 环城西路
# 正在处理第276条路： 火龙地路
# 正在处理第277条路： 毕昇路
# 正在处理第278条路： 徽中路
# 正在处理第279条路： 田埠西路
# 正在处理第280条路： 叠嶂路
# 正在处理第281条路： 合巢路
# 正在处理第282条路： 国三路
# 正在处理第283条路： 龙河路
# 正在处理第284条路： 阜阳路
# 正在处理第285条路： 四里河路四里河高架
# 正在处理第286条路： 屏山路
# 正在处理第287条路： 四里河路
# 正在处理第288条路： 嘉陵江路
# 正在处理第289条路： 新安江路
# 正在处理第290条路： 科技园路
# 正在处理第291条路： 店费路
# 正在处理第292条路： 环城东路
# 正在处理第293条路： 少泉湖隧道
# 正在处理第294条路： 石笋路
# 正在处理第295条路： 龙图路
# 正在处理第296条路： 永和路
# 正在处理第297条路： 南一环路
# 正在处理第298条路： 少荃街
# 正在处理第299条路： 长江中路
# 正在处理第300条路： 合钢桥
# 正在处理第301条路： 合白路
# 正在处理第302条路： 双凤路
# 正在处理第303条路： 万年埠路
# 正在处理第304条路： 浮莲路
# 正在处理第305条路： 土山路
# 正在处理第306条路： 望江西路
# 正在处理第307条路： 王步文路
# 正在处理第308条路： 青阳路
# 正在处理第309条路： 银杏路
# 正在处理第310条路： 寿春路
# 正在处理第311条路： 乐水路
# 正在处理第312条路： 成都路
# 正在处理第313条路： 江苏路
# 正在处理第314条路： 文山路
# 正在处理第315条路： 团结路
# 正在处理第316条路： 大郭路
# 正在处理第317条路： 庐江路
# 正在处理第318条路： 利辛路
# 正在处理第319条路： 合蚌路
# 正在处理第320条路： 老街
# 正在处理第321条路： 润河路
# 正在处理第322条路： 金寨路
# 正在处理第323条路： 环湖北路观光车道
# 正在处理第324条路： 亳州路桥
# 正在处理第325条路： 天柱山大道
# 正在处理第326条路： 蜀山东路
# 正在处理第327条路： 玉带桥
# 正在处理第328条路： 史河路
# 正在处理第329条路： JAC大道
# 正在处理第330条路： 凤庆路
# 正在处理第331条路： 新海大道
# 正在处理第332条路： 落客平台
# 正在处理第333条路： 长白山路
# 正在处理第334条路： 庐州大道
# 正在处理第335条路： 康乐路
# 正在处理第336条路： 南湾路
# 正在处理第337条路： 科学岛路
# 正在处理第338条路： 彩虹路
# 正在处理第339条路： 华南大道
# 正在处理第340条路： 支河路
# 正在处理第341条路： 灵石路
# 正在处理第342条路： 西宁路
# 正在处理第343条路： 檀香路
# 正在处理第344条路： 香樟大道
# 正在处理第345条路： 望江东路辅路
# 正在处理第346条路： 星光大道
# 正在处理第347条路： 明珠大道
# 正在处理第348条路： 包河大道桥
# 正在处理第349条路： 潜山路
# 正在处理第350条路： 金寨南路
# 正在处理第351条路： 汤口路
# 正在处理第352条路： 怀远路
# 正在处理第353条路： 金桂路
# 正在处理第354条路： 站东路
# 正在处理第355条路： 龙感湖路
# 正在处理第356条路： 桃枝路
# 正在处理第357条路： 栏滨路
# 正在处理第358条路： 撮镇路
# 正在处理第359条路： 严刘路
# 正在处理第360条路： 复兴路
# 正在处理第361条路： 磨黄路
# 正在处理第362条路： 浙江路
# 正在处理第363条路： 裕溪路桥
# 正在处理第364条路： 宿州路
# 正在处理第365条路： 石楠路
# 正在处理第366条路： 宣城路
# 正在处理第367条路： 南京路
# 正在处理第368条路： 烔炀路
# 正在处理第369条路： 双塘路
# 正在处理第370条路： 阊水路
# 正在处理第371条路： 祥和路
# 正在处理第372条路： 金寨南路辅道
# 正在处理第373条路： 金炉路
# 正在处理第374条路： 安庆路
# 正在处理第375条路： 林湖路
# 正在处理第376条路： 翡翠路
# 正在处理第377条路： 徽州大道辅道
# 正在处理第378条路： 派河大桥
# 正在处理第379条路： 山东路
# 正在处理第380条路： 茨河路
# 正在处理第381条路： 枞阳路
# 正在处理第382条路： 大众路
# 正在处理第383条路： 中山路桥
# 正在处理第384条路： 肥西路
# 正在处理第385条路： 文忠路
# 正在处理第386条路： 长沙路桥
# 正在处理第387条路： 瑞丰路
# 正在处理第388条路： 红星路
# 正在处理第389条路： 绩溪路
# 正在处理第390条路： 连水路
# 正在处理第391条路： 明皇路桥
# 正在处理第392条路： 站西路
# 正在处理第393条路： 兴烔路
# 正在处理第394条路： 西落客平台
# 正在处理第395条路： 长丰路桥
# 正在处理第396条路： 亳州路
# 正在处理第397条路： 巢湖南路
# 正在处理第398条路： 汕头路
# 正在处理第399条路： 临泉路
# 正在处理第400条路： 松林路
# 正在处理第401条路： 万泽路
# 正在处理第402条路： 北二环路
# 正在处理第403条路： 站塘路
# 正在处理第404条路： 西安路
# 正在处理第405条路： 冯城街
# 正在处理第406条路： 温合线
# 正在处理第407条路： 黄山路
# 正在处理第408条路： 金池路
# 正在处理第409条路： 呈坎路
# 正在处理第410条路： 君山路
# 正在处理第411条路： 宏图大道
# 正在处理第412条路： 正阳路
# 正在处理第413条路： 万泉河路
# 正在处理第414条路： 敬亭山路
# 正在处理第415条路： 香怡路
# 正在处理第416条路： 义和商业街
# 正在处理第417条路： 丹霞西路
# 正在处理第418条路： 少荃湖隧道
# 正在处理第419条路： 翠竹路
# 正在处理第420条路： 梅山桥
# 正在处理第421条路： 凤淮路
# 正在处理第422条路： 龙蟠路
# 正在处理第423条路： 国际大道
# 正在处理第424条路： 天海路
# 正在处理第425条路： 东风大道
# 正在处理第426条路： 高铁路
# 正在处理第427条路： 桐城南路
# 正在处理第428条路： 磨店街
# 正在处理第429条路： 官亭路
# 正在处理第430条路： 青翠路
# 正在处理第431条路： 元店路
# 正在处理第432条路： 方兴湖隧道
# 正在处理第433条路： 清溪路
# 正在处理第434条路： 天达路
# 正在处理第435条路： 淮海大道
# 正在处理第436条路： 湖东路
# 正在处理第437条路： 八公山路
# 正在处理第438条路： 太原路
# 正在处理第439条路： 董铺路
# 正在处理第440条路： 海南路
# 正在处理第441条路： 公园路
# 正在处理第442条路： 洞庭湖路
# 正在处理第443条路： 马家渡大桥
# 正在处理第444条路： 长安路
# 正在处理第445条路： 长松路
# 正在处理第446条路： 金富路
# 正在处理第447条路： 建设路
# 正在处理第448条路： 翡翠桥
# 正在处理第449条路： 肥西路桥
# 正在处理第450条路： 岱河路
# 正在处理第451条路： 紫云路桥
# 正在处理第452条路： 上海路
# 正在处理第453条路： 圩新路
# 正在处理第454条路： 东方大道
# 正在处理第455条路： 南含山路
# 正在处理第456条路： 清源路桥
# 正在处理第457条路： 叠翠峰路
# 正在处理第458条路： 科学大道
# 正在处理第459条路： 霍山路
# 正在处理第460条路： 习友南路
# 正在处理第461条路： 银杏大道
# 正在处理第462条路： 浮槎山路
# 正在处理第463条路： 双墩路
# 正在处理第464条路： 贵池路
# 正在处理第465条路： 社岗路
# 正在处理第466条路： 合作化南路
# 正在处理第467条路： 华阳路
# 正在处理第468条路： 颍河路
# 正在处理第469条路： 前岭路
# 正在处理第470条路： 龙泉大街
# 正在处理第471条路： 环城南路
# 正在处理第472条路： 月亮湾路
# 正在处理第473条路： 菩提大道
# 正在处理第474条路： 屯溪路桥
# 正在处理第475条路： 双水路
# 正在处理第476条路： 沈东路
# 正在处理第477条路： 烔黄路
# 正在处理第478条路： 国二路
# 正在处理第479条路： 无为路
# 正在处理第480条路： 潜水西路
# 正在处理第481条路： 南宁东路
# 正在处理第482条路： 姜家湖路
# 正在处理第483条路： 十五里河桥
# 正在处理第484条路： 徽华路
# 正在处理第485条路： 天山路
# 正在处理第486条路： 汶水路
# 正在处理第487条路： 安乐路
# 正在处理第488条路： 长江东大街桥
# 正在处理第489条路： 涂山路
# 正在处理第490条路： 人民路
# 正在处理第491条路： 武汉路
# 正在处理第492条路： 襄河路
# 正在处理第493条路： 长沙路
# 正在处理第494条路： 嵩山路
# 正在处理第495条路： 寿春路桥
# 正在处理第496条路： 芜湖路
# 正在处理第497条路： 怀宁南路
# 正在处理第498条路： 合掌路
# 正在处理第499条路： 阜南路
# 正在处理第500条路： 天通路
# 正在处理第501条路： 云谷路
# 正在处理第502条路： 凤锦路
# 正在处理第503条路： 青龙路
# 正在处理第504条路： 粮站路
# 正在处理第505条路： 龙子湖路
# 正在处理第506条路： 和平路下穿桥
# 正在处理第507条路： 天龙路
# 正在处理第508条路： 机场便道
# 正在处理第509条路： 集贤路
# 正在处理第510条路： 北街
# 正在处理第511条路： 谷河路
# 正在处理第512条路： 怀宁路
# 正在处理第513条路： 天都路
# 正在处理第514条路： 金江路
# 正在处理第515条路： 大创路
# 正在处理第516条路： 玉龙路
# 正在处理第517条路： 大龙山路
# 正在处理第518条路： 固镇路
# 正在处理第519条路： 延乔路
# 正在处理第520条路： 淝河路
# 正在处理第521条路： 灵壁路
# 正在处理第522条路： 海关路
# 正在处理第523条路： 香蒲路
# 正在处理第524条路： 金珠路
# 正在处理第525条路： 北含山路
# 正在处理第526条路： 徽州大道桥
# 正在处理第527条路： 通达路
# 正在处理第528条路： 龙灯路
# 正在处理第529条路： 天柱路
# 正在处理第530条路： 昌盛路
# 正在处理第531条路： 宁西路
# 正在处理第532条路： 包公大道
# 正在处理第533条路： 裕丰路
# 正在处理第534条路： 长江西路
# 正在处理第535条路： 天竹路
# 正在处理第536条路： 深圳路
# 正在处理第537条路： 金兰路
# 正在处理第538条路： 凤凰桥路
# 正在处理第539条路： 烔中路
# 正在处理第540条路： 龙潭桥
# 正在处理第541条路： 沿河西路桥
# 正在处理第542条路： 养正路
# 正在处理第543条路： 北雁湾路
# 正在处理第544条路： 西一环路
# 正在处理第545条路： 歙县路
# 正在处理第546条路： 阜阳北路
# 正在处理第547条路： 繁华大道大桥
# 正在处理第548条路： 淮河路
# 正在处理第549条路： 兴业大道
# 正在处理第550条路： 青年路
# 正在处理第551条路： 出口：潜山路 习友路
# 正在处理第552条路： 新汴河路
# 正在处理第553条路： 淮河西路
# 正在处理第554条路： 临泉路跨二十埠河桥
# 正在处理第555条路： 卧云路
# 正在处理第556条路： 岳西路
# 正在处理第557条路： 铁笛路
# 正在处理第558条路： 四川路
# 正在处理第559条路： 濛河路
# 正在处理第560条路： 学府路
# 正在处理第561条路： 通淮中路
# 正在处理第562条路： 四顶山路
# 正在处理第563条路： 袁大路
# 正在处理第564条路： 贵州路
# 正在处理第565条路： 金阳路
# 正在处理第566条路： 宣城路桥
# 正在处理第567条路： 迎宾路
# 正在处理第568条路： 宋斗湾路
# 正在处理第569条路： 甘泉路
# 正在处理第570条路： 扬子江路
# 正在处理第571条路： 万佛湖路
# 正在处理第572条路： 佛子岭路
# 正在处理第573条路： 冬至路
# 正在处理第574条路： 长江中路辅路
# 正在处理第575条路： 凤麟路
# 正在处理第576条路： 迎淮路
# 正在处理第577条路： 松荫桥
# 正在处理第578条路： 铜陵路高架
# 正在处理第579条路： 高王桥
# 正在处理第580条路： 扶疏路
# 正在处理第581条路： 拱辰门桥
# 正在处理第582条路： 星光西路
# 正在处理第583条路： 太湖路
# 正在处理第584条路： 玉屏路
# 正在处理第585条路： 北海路
# 正在处理第586条路： 花园大道
# 正在处理第587条路： 采石路
# 正在处理第588条路： 马鞍山路
# 正在处理第589条路： 幸福路
# 正在处理第590条路： 北一环路
# 正在处理第591条路： 金安路
# 正在处理第592条路： 长江路桥
# 正在处理第593条路： 定远路
# 正在处理第594条路： 孝肃桥
# 正在处理第595条路： 环湖北路
# 正在处理第596条路： 相城路
# 正在处理第597条路： 机场高速
# 正在处理第598条路： 莲花路
# 正在处理第599条路： 佛掌南路
# 正在处理第600条路： 合瓦路
# 正在处理第601条路： 沿河东路
# 正在处理第602条路： 延安路
# 正在处理第603条路： 站前东路
# 正在处理第604条路： 西淝河路
# 正在处理第605条路： 荷花路
# 正在处理第606条路： 巢湖路
# 正在处理第607条路： 潜口路
# 正在处理第608条路： 大别山路
# 正在处理第609条路： 珠江路
# 正在处理第610条路： 省道105
# 正在处理第611条路： 肥东路
# 正在处理第612条路： 兰州路
# 正在处理第613条路： 板桥河沿河路
# 正在处理第614条路： 聚星桥
# 正在处理第615条路： 衡山路
# 正在处理第616条路： 紫石路
# 正在处理第617条路： 裕溪路
# 正在处理第618条路： 庐州大道桥
# 正在处理第619条路： 金宁路
# 正在处理第620条路： 横大路
# 正在处理第621条路： 天鹅湖路
# 正在处理第622条路： 迎松路
# 正在处理第623条路： 新街
# 正在处理第624条路： 始信路
# 正在处理第625条路： 空港南路
# 正在处理第626条路： 习友路
# 正在处理第627条路： 合作化路
# 正在处理第628条路： 龙湖路
# 正在处理第629条路： 城西湖路
# 正在处理第630条路： 前江路
# 正在处理第631条路： 奎河路
# 正在处理第632条路： 合马路
# 正在处理第633条路： 龙岗路桥
# 正在处理第634条路： 金峰路
# 正在处理第635条路： 宁国南路
# 正在处理第636条路： 南二环路
# 正在处理第637条路： 徽强路
# 正在处理第638条路： 雪霁路
# 正在处理第639条路： 神龙路
# 正在处理第640条路： 嘉山路桥
# 正在处理第641条路： 铭传路
# 正在处理第642条路： 三角线桥
# 正在处理第643条路： 金岗大道
# 正在处理第644条路： 梦溪路
# 正在处理第645条路： 蒙河路
# 正在处理第646条路： 半岛路
# 正在处理第647条路： 南屏路
# 正在处理第648条路： 环翠路
# 正在处理第649条路： 兴旺路
# 正在处理第650条路： 旺兴街
# 正在处理第651条路： 省人大 芜湖路出口
# 正在处理第652条路： 馆驿路
# 正在处理第653条路： 内蒙路
# 正在处理第654条路： 高刘路
# 正在处理第655条路： 湖南路
# 正在处理第656条路： 曹营街
# 正在处理第657条路： 水西门桥
# 正在处理第658条路： 夏园路
# 正在处理第659条路： 宿松路
# 正在处理第660条路： 花园街
# 正在处理第661条路： 蓬莱路
# 正在处理第662条路： 紫云路
# 正在处理第663条路： 荷塘路
# 正在处理第664条路： 新蚌埠路
# 正在处理第665条路： 相山路
# 正在处理第666条路： 梁古大街
# 正在处理第667条路： 环巢湖大道
# 正在处理第668条路： 皖水路
# 正在处理第669条路： 炯炀河桥
# 正在处理第670条路： 南陵路
# 正在处理第671条路： 项王东路
# 正在处理第672条路： 西园西路
# 正在处理第673条路： 城东湖路
# 正在处理第674条路： 乐平路
# 正在处理第675条路： 皇嘉路
# 正在处理第676条路： 河南路
# 正在处理第677条路： 龙川路
# 正在处理第678条路： 体育路
# 正在处理第679条路： 武里山路
# 正在处理第680条路： 芦岭路
# 正在处理第681条路： 包河大道高架
# 正在处理第682条路： 南淝河大桥
# 正在处理第683条路： 华三路
# 正在处理第684条路： 长江西路高架桥
# 正在处理第685条路： 太子山路
# 正在处理第686条路： 黄河路
# 正在处理第687条路： 繁华大道
# 正在处理第688条路： 凤霞路
# 正在处理第689条路： 磨子潭路
# 正在处理第690条路： 六安路
# 正在处理第691条路： 北一环四里河高架
# 正在处理第692条路： 凤台路
# 正在处理第693条路： 钟油坊路
# 正在处理第694条路： 桂王路
# 正在处理第695条路： 长乐路
# 正在处理第696条路： 福山路
# 正在处理第697条路： 哈尔滨路
# 正在处理第698条路： 万佛山路
# 正在处理第699条路： 引针路
# 正在处理第700条路： 龙门岭路
# 正在处理第701条路： 沁源路
# 正在处理第702条路： 响洪甸路
# 正在处理第703条路： 青年北路
# 正在处理第704条路： 徽州大道高架
# 正在处理第705条路： 陵园路
# 正在处理第706条路： 壶天路
# 正在处理第707条路： 杨林路
# 正在处理第708条路： 栏滨路上跨合芜高速大桥
# 正在处理第709条路： 明光路桥
# 正在处理第710条路： 出口：高速
# 正在处理第711条路： 沿河西路
# 正在处理第712条路： 中心街
# 正在处理第713条路： 石柱路
# 正在处理第714条路： 铜陵北路
# 正在处理第715条路： 舒城路
# 正在处理第716条路： 安盛路
# 正在处理第717条路： 棋石路
# 正在处理第718条路： 南宁西路
# 正在处理第719条路： 水阳江路
# 正在处理第720条路： 寿春东路
# 正在处理第721条路： 望江东路
# 正在处理第722条路： 锦绣大道
# 正在处理第723条路： 青鸾路
# 正在处理第724条路： 金蓉路
# 正在处理第725条路： 仙人路
# 正在处理第726条路： 瑯玡山路
# 正在处理第727条路： 明皇路
# 正在处理第728条路： 济河路
# 正在处理第729条路： 芜湖路辅路
# 正在处理第730条路： 东二环路
# 正在处理第731条路： 创新大道
# 正在处理第732条路： 丹霞路
# 正在处理第733条路： 徽毫路
# 正在处理第734条路： 徽州大道
# 正在处理第735条路： 合作化南路高架桥
# 正在处理第736条路： 虹桥
# 正在处理第737条路： 樊洼路
# 正在处理第738条路： 菱湖路
# 正在处理第739条路： 雨山路
# 正在处理第740条路： 合水路
# 正在处理第741条路： 程长庚路
# 正在处理第742条路： 云海路
# 正在处理第743条路： 澳门路
# 正在处理第744条路： 稻香路
# 正在处理第745条路： 东二环路高架
# 正在处理第746条路： 长宁大道
# 正在处理第747条路： 胜利路立交桥
# 正在处理第748条路： 芦花路
# 正在处理第749条路： 杨井路
# 正在处理第750条路： 育才路
# 正在处理第751条路： 福州路
# 正在处理第752条路： 中山路
# 正在处理第753条路： 宋斗湾桥
# 正在处理第754条路： 蒙城路
# 正在处理第755条路： 振兴路
# 正在处理第756条路： 长春街
# 正在处理第757条路： 新安江路桥
# 正在处理第758条路： 宁国路
# 正在处理第759条路： 西藏路
# 正在处理第760条路： 长江东路
# 正在处理第761条路： 长江东路桥
# 正在处理第762条路： 全椒路（公交专用）
# 正在处理第763条路： 石台路
# 正在处理第764条路： 广西路
# 正在处理第765条路： 嘉山路
# 处理了766条路

# %%
df[df['roadName']=='淝河路']
# Out:
#      roadName   roadType             timestamp        user version      wayID
# 2261      淝河路   tertiary  2017-06-23T14:37:57Z  Virgil Guo       9  195681475
# 2262      淝河路  secondary  2017-08-24T04:54:28Z  Virgil Guo      13  195681496
# 2263      淝河路  secondary  2017-08-24T04:54:26Z  Virgil Guo       1  518172602

# %%
df_fei=df[df['roadName']=='淝河路']

# %%
df_fei.reset_index(inplace=True)

# %%
df_fei
# Out:
#    index roadName   roadType             timestamp        user version  \
# 0   2261      淝河路   tertiary  2017-06-23T14:37:57Z  Virgil Guo       9
# 1   2262      淝河路  secondary  2017-08-24T04:54:28Z  Virgil Guo      13
# 2   2263      淝河路  secondary  2017-08-24T04:54:26Z  Virgil Guo       1
#
#        wayID
# 0  195681475
# 1  195681496
# 2  518172602

# %%
# 当出现多人上传了某类型路段，则选择topK个最新的记录
topK = 3

'''
先按照roadType聚合，在同一个roadType中，按照用户聚合，
'''
count = 0
newRoadDataFrame = pd.DataFrame(columns=['index', 'roadName', 'wayID', 'roadType', 'user', 'timestamp', 'version'])
roadDataFrame=df_fei
def func(dfGroupByRoadType):
    timestamp_index_dict = defaultdict(lambda: 0)
    global newRoadDataFrame
    global count
    roadDataFrame
    if (count != 0):
        print('count!=0')
        print(dfGroupByRoadType)
        for user,dfGroupByRoadTypeGroupByUser in dfGroupByRoadType.groupby('user'):
            print(type(dfGroupByRoadTypeGroupByUser))
            dfGroupByRoadTypeGroupByUser.sort_values('timestamp', ascending=False, inplace=True)
            timestamp_index_dict[
                dfGroupByRoadTypeGroupByUser.iloc[0]['timestamp']] = dfGroupByRoadTypeGroupByUser.iloc[0][
                'index']
        timestamp_index_list = sorted(timestamp_index_dict.items(), reverse=True)
        rang = topK if (topK < len(timestamp_index_list)) else len(timestamp_index_list)
        print('rang:{}'.format(rang))
        for i in range(rang):
            print('timestamp_index_list[{}]:{}'.format(i,timestamp_index_list[i]))
            print(timestamp_index_list[i][1])
            newRoadDataFrame = pd.concat([newRoadDataFrame, roadDataFrame[roadDataFrame['index'] == [timestamp_index_list[i][1]]]],
                                         ignore_index=True)

    count += 1


df_fei.groupby('roadType').apply(func)
# Out:
# count!=0
#    index roadName   roadType             timestamp        user version  \
# 1   2262      淝河路  secondary  2017-08-24T04:54:28Z  Virgil Guo      13
# 2   2263      淝河路  secondary  2017-08-24T04:54:26Z  Virgil Guo       1
#
#        wayID
# 1  195681496
# 2  518172602
# <class 'pandas.core.frame.DataFrame'>
# rang:1
# timestamp_index_list[0]:('2017-08-24T04:54:28Z', 2262)
# 2262
# count!=0
#    index roadName  roadType             timestamp        user version  \
# 0   2261      淝河路  tertiary  2017-06-23T14:37:57Z  Virgil Guo       9
#
#        wayID
# 0  195681475
# <class 'pandas.core.frame.DataFrame'>
# rang:1
# timestamp_index_list[0]:('2017-06-23T14:37:57Z', 2261)
# 2261
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_fei
# Out:
#    index roadName   roadType             timestamp        user version  \
# 0   2261      淝河路   tertiary  2017-06-23T14:37:57Z  Virgil Guo       9
# 1   2262      淝河路  secondary  2017-08-24T04:54:28Z  Virgil Guo      13
# 2   2263      淝河路  secondary  2017-08-24T04:54:26Z  Virgil Guo       1
#
#        wayID
# 0  195681475
# 1  195681496
# 2  518172602

# %%
newRoadDataFrame
# Out:
#   index roadName   roadType             timestamp        user version  \
# 0  2262      淝河路  secondary  2017-08-24T04:54:28Z  Virgil Guo      13
# 1  2261      淝河路   tertiary  2017-06-23T14:37:57Z  Virgil Guo       9
#
#        wayID
# 0  195681496
# 1  195681475

# %%
df_fei.groupby('roadType').apply(func)
# Out:
#    index roadName   roadType             timestamp        user version  \
# 1   2262      淝河路  secondary  2017-08-24T04:54:28Z  Virgil Guo      13
# 2   2263      淝河路  secondary  2017-08-24T04:54:26Z  Virgil Guo       1
#
#        wayID
# 1  195681496
# 2  518172602
#    index roadName  roadType             timestamp        user version  \
# 0   2261      淝河路  tertiary  2017-06-23T14:37:57Z  Virgil Guo       9
#
#        wayID
# 0  195681475
# Empty DataFrame
# Columns: []
# Index: []

# %%
for roadType,df in df_fei.groupby('roadType'):
    print(roadType)
    print(df.sort_values('timestamp', ascending=False))
# Out:
# secondary
#    index roadName   roadType             timestamp        user version  \
# 1   2262      淝河路  secondary  2017-08-24T04:54:28Z  Virgil Guo      13
# 2   2263      淝河路  secondary  2017-08-24T04:54:26Z  Virgil Guo       1
#
#        wayID
# 1  195681496
# 2  518172602
# tertiary
#    index roadName  roadType             timestamp        user version  \
# 0   2261      淝河路  tertiary  2017-06-23T14:37:57Z  Virgil Guo       9
#
#        wayID
# 0  195681475

# %%
dic = defaultdict(lambda: 0)

# %%
dic['b']=1
dic['a']=2
dic['c']=-1

# %%
sorted(dic.items(),reverse=True)
# Out:
# [('c', -1), ('b', 1), ('a', 2)]

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
# @Date    : 2018-04-16 18:24:00
# @Author  : guanglinzhou (xdzgl812@163.com)
# @Link    : https://github.com/GuanglinZhou
# @Version : $Id$

# 获取一个表格,列名如下：
# 路名，WayID，类型(secondary)，user,version,timestamp

import os
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pandas as pd


# 路网中有的路名仅使用了拼音，检测并剔除
def contain_zh(word):
    '''
    判断传入字符串是否包含中文
    :param word: 待判断字符串
    :return: True:包含中文  False:不包含中文
    '''
    zh_pattern = re.compile(u'[\u4e00-\u9fa5]+')
    match = zh_pattern.search(word)
    return match


# 返回路网中所有路名
def getRoadNameSet(tree):
    roadNameSet = set()
    roadTypeList = ['primary', 'primary_link', 'secondary', 'secondary_link', 'tertiary', 'tertiary_link', 'trunk',
                    'trunk_link']
    num=0
    for elem in tree.iter(tag='way'):
        tag_k = elem.findall('tag')
        for tag in tag_k:
            if (tag.attrib['k'] == 'highway' and tag.attrib['v'] not in roadTypeList):
                break
            if (tag.attrib['k'] == 'name'):
                roadName = tag.attrib['v']
                if (contain_zh(roadName)):
                    roadNameSet.add(roadName)
                else:
                    print(roadName)
        num+=1
        if(num==100):
            break
    return roadNameSet

# 根据路名获取路网中道路相关的路段wayid,构建道路表
def constructRoadDataFrame(tree, roadNameSet):
    # 当出现多人上传了某类型路段，则选择topK个最新的记录
    roadDataFrame = pd.DataFrame(columns=['roadName', 'wayID', 'roadType', 'user', 'timestamp', 'version'])
    roadInfo = defaultdict(lambda: 0)
    roadType = ''
    roadNum = 0
    for roadName in roadNameSet:
        print('正在处理第{}条路： {}'.format(roadNum, roadName))
        roadNum += 1
        for elem in tree.iter(tag='way'):
            tag_k = elem.findall('tag')
            for tag in tag_k:
                if (tag.attrib['k'] == 'highway'):
                    roadType = tag.attrib['v']
                if (tag.attrib['k'] == 'name'):
                    if (tag.attrib['v'] == roadName):
                        roadInfo['roadName'] = roadName
                        roadInfo['wayID'] = elem.attrib['id']
                        roadInfo['roadType'] = roadType
                        roadInfo['user'] = elem.attrib['user']
                        roadInfo['timestamp'] = elem.attrib['timestamp']
                        roadInfo['version'] = elem.attrib['version']
                        tempDF = pd.DataFrame([roadInfo])
                        roadDataFrame = pd.concat([roadDataFrame, tempDF], ignore_index=True)

    return roadDataFrame
    

tree = ET.ElementTree(file='hefei_highways.osm')
root = tree.getroot()
roadNameSet = set(['翡翠路'])
roadTable = pd.DataFrame(columns=['index', 'roadName', 'wayID', 'roadType', 'user', 'timestamp', 'version'])
roadDataFrame = constructRoadDataFrame(tree, roadNameSet)
# Out:
# 正在处理第0条路： 翡翠路

# %%
def func(dfGroupByRoadType):
    timestamp_index_dict = defaultdict(lambda: 0)
    global count
    global roadTable
    print('count:{}'.format(count))
    if (count != 0):
        print(dfGroupByRoadType)
        for user, dfGroupByRoadTypeGroupByUser in dfGroupByRoadType.groupby('user'):
            dfGroupByRoadTypeGroupByUser.sort_values('timestamp', ascending=False, inplace=True)
            timestamp_index_dict[
                dfGroupByRoadTypeGroupByUser.iloc[0]['timestamp']] = dfGroupByRoadTypeGroupByUser.iloc[0][
                'index']
        timestamp_index_list = sorted(timestamp_index_dict.items(), reverse=True)
        rang = topK if (topK < len(timestamp_index_list)) else len(timestamp_index_list)
        for i in range(rang):
            roadTable = pd.concat(
                [roadTable, roadDataFrame[roadDataFrame['index'] == [timestamp_index_list[i][1]]]],
                ignore_index=True)

    count += 1
def constructRoadTable(tree, roadDataFrame):
    topK = 3
    roadDataFrame.reset_index(inplace=True)
    roadDataFrame.groupby('roadType').apply(func)
count=0
constructRoadTable(tree, roadDataFrame)
# Out:
# count:0
# count:1
#     index roadName roadType             timestamp         user version  \
# 0       0      翡翠路  primary  2017-08-29T14:10:08Z   Virgil Guo      21
# 1       1      翡翠路  primary  2016-02-19T00:24:55Z  Nodes&Roads       8
# 2       2      翡翠路  primary  2014-09-12T15:59:15Z          汤鹏程       3
# 3       3      翡翠路  primary  2016-05-31T15:11:03Z  Boyuan Yang       3
# 4       4      翡翠路  primary  2018-02-12T15:30:09Z  Seandebasti      17
# 5       5      翡翠路  primary  2017-08-29T14:10:09Z   Virgil Guo       9
# 6       6      翡翠路  primary  2016-05-31T15:11:02Z  Boyuan Yang       3
# 7       7      翡翠路  primary  2016-01-28T15:03:13Z   Virgil Guo       5
# 8       8      翡翠路  primary  2017-09-21T18:44:06Z   Virgil Guo       4
# 9       9      翡翠路  primary  2017-09-21T18:44:06Z   Virgil Guo       5
# 10     10      翡翠路  primary  2017-09-21T18:43:57Z   Virgil Guo       6
# 11     11      翡翠路  primary  2018-03-22T02:05:09Z   Virgil Guo       9
# 12     12      翡翠路  primary  2016-02-13T17:07:33Z   Virgil Guo       2
# 13     13      翡翠路  primary  2016-02-13T17:07:33Z   Virgil Guo       2
# 14     14      翡翠路  primary  2018-02-25T04:54:15Z   Virgil Guo      10
# 15     15      翡翠路  primary  2017-09-21T18:43:58Z   Virgil Guo      10
# 16     16      翡翠路  primary  2016-02-13T17:07:35Z   Virgil Guo       2
# 17     17      翡翠路  primary  2015-02-24T15:20:21Z          AUV       7
# 18     18      翡翠路  primary  2017-05-14T06:58:38Z   Virgil Guo      10
# 19     19      翡翠路  primary  2017-08-23T07:57:14Z   Virgil Guo       2
# 20     20      翡翠路  primary  2017-05-14T06:58:31Z   Virgil Guo       1
# 21     21      翡翠路  primary  2017-05-14T06:58:31Z   Virgil Guo       1
# 22     22      翡翠路  primary  2017-08-03T05:56:35Z   Virgil Guo       2
# 23     23      翡翠路  primary  2018-02-12T15:30:09Z  Seandebasti       2
# 24     24      翡翠路  primary  2017-08-23T07:57:03Z   Virgil Guo       1
# 25     25      翡翠路  primary  2017-09-16T05:45:11Z   Virgil Guo       3
# 26     26      翡翠路  primary  2017-08-23T07:57:07Z   Virgil Guo       1
# 27     27      翡翠路  primary  2017-08-29T14:09:59Z   Virgil Guo       1
# 28     28      翡翠路  primary  2017-08-29T14:10:00Z   Virgil Guo       1
# 29     29      翡翠路  primary  2017-08-29T14:10:05Z   Virgil Guo       1
# 30     30      翡翠路  primary  2017-09-21T18:43:49Z   Virgil Guo       1
# 31     31      翡翠路  primary  2017-09-21T18:43:49Z   Virgil Guo       1
# 32     32      翡翠路  primary  2017-09-21T18:43:52Z   Virgil Guo       1
# 33     33      翡翠路  primary  2017-09-21T18:43:52Z   Virgil Guo       1
#
#         wayID
# 0    24568371
# 1   115331105
# 2   115331106
# 3   115331108
# 4   243273757
# 5   246315658
# 6   290510409
# 7   290510410
# 8   290510412
# 9   303060220
# 10  303060221
# 11  303060222
# 12  303060223
# 13  303060224
# 14  303060225
# 15  303060428
# 16  303060429
# 17  324769654
# 18  324909396
# 19  493388195
# 20  493388196
# 21  493388197
# 22  493388198
# 23  517875576
# 24  517875577
# 25  517875623
# 26  517875625
# 27  519659345
# 28  519659351
# 29  519659443
# 30  526554801
# 31  526554802
# 32  526554831
# 33  526554833

# %%
roadTable
# Out:
#   index roadName roadType             timestamp         user version  \
# 0    11      翡翠路  primary  2018-03-22T02:05:09Z   Virgil Guo       9
# 1     4      翡翠路  primary  2018-02-12T15:30:09Z  Seandebasti      17
# 2     3      翡翠路  primary  2016-05-31T15:11:03Z  Boyuan Yang       3
#
#        wayID
# 0  303060222
# 1  243273757
# 2  115331108

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
# @Date    : 2018-04-16 18:24:00
# @Author  : guanglinzhou (xdzgl812@163.com)
# @Link    : https://github.com/GuanglinZhou
# @Version : $Id$

# 获取一个表格,列名如下：
# 路名，WayID，类型(secondary)，user,version,timestamp

import os
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pandas as pd


# 路网中有的路名仅使用了拼音，检测并剔除
def contain_zh(word):
    '''
    判断传入字符串是否包含中文
    :param word: 待判断字符串
    :return: True:包含中文  False:不包含中文
    '''
    zh_pattern = re.compile(u'[\u4e00-\u9fa5]+')
    match = zh_pattern.search(word)
    return match


# 返回路网中所有路名
def getRoadNameSet(tree):
    roadNameSet = set()
    roadTypeList = ['primary', 'primary_link', 'secondary', 'secondary_link', 'tertiary', 'tertiary_link', 'trunk',
                    'trunk_link']
    for elem in tree.iter(tag='way'):
        tag_k = elem.findall('tag')
        for tag in tag_k:
            if (tag.attrib['k'] == 'highway' and tag.attrib['v'] not in roadTypeList):
                break
            if (tag.attrib['k'] == 'name'):
                roadName = tag.attrib['v']
                if (contain_zh(roadName)):
                    roadNameSet.add(roadName)
                else:
                    print(roadName)
    return roadNameSet


# 根据路名获取路网中道路相关的路段wayid,构建道路表
def constructRoadDataFrame(tree, roadNameSet):
    # 当出现多人上传了某类型路段，则选择topK个最新的记录
    roadDataFrame = pd.DataFrame(columns=['roadName', 'wayID', 'roadType', 'user', 'timestamp', 'version'])
    roadTypeList = ['primary', 'primary_link', 'secondary', 'secondary_link', 'tertiary', 'tertiary_link', 'trunk',
                    'trunk_link']
    roadInfo = defaultdict(lambda: 0)
    roadType = ''
    roadNum = 0
    for roadName in roadNameSet:
        print('正在处理第{}条路： {}'.format(roadNum, roadName))
        roadNum += 1
        for elem in tree.iter(tag='way'):
            tag_k = elem.findall('tag')
            for tag in tag_k:
#                 if (tag.attrib['k'] == 'highway'):
#                     roadType = tag.attrib['v']
                if (tag.attrib['k'] == 'highway' and tag.attrib['v'] in roadTypeList):
                    roadType = tag.attrib['v']

#                 print('roadType:{}'.format(roadType))
                if (tag.attrib['k'] == 'name'):
                    if (tag.attrib['v'] == roadName):
                        roadInfo['roadName'] = roadName
                        roadInfo['wayID'] = elem.attrib['id']
                        roadInfo['roadType'] = roadType
                        roadInfo['user'] = elem.attrib['user']
                        roadInfo['timestamp'] = elem.attrib['timestamp']
                        roadInfo['version'] = elem.attrib['version']
                        tempDF = pd.DataFrame([roadInfo])
                        roadDataFrame = pd.concat([roadDataFrame, tempDF], ignore_index=True)

    return roadDataFrame


# 先按照roadType聚合，在同一个roadType中，按照用户聚合，


def constructRoadTable(tree, roadDataFrame):
    topK = 3

    def func(dfGroupByRoadType):
        timestamp_index_dict = defaultdict(lambda: 0)
        global count
        global roadTable
        if (count != 0):
            print(dfGroupByRoadType)
            for user, dfGroupByRoadTypeGroupByUser in dfGroupByRoadType.groupby('user'):
                dfGroupByRoadTypeGroupByUser.sort_values('timestamp', ascending=False, inplace=True)
                timestamp_index_dict[
                    dfGroupByRoadTypeGroupByUser.iloc[0]['timestamp']] = dfGroupByRoadTypeGroupByUser.iloc[0][
                    'index']
            timestamp_index_list = sorted(timestamp_index_dict.items(), reverse=True)
            rang = topK if (topK < len(timestamp_index_list)) else len(timestamp_index_list)
            for i in range(rang):
                roadTable = pd.concat(
                    [roadTable, roadDataFrame[roadDataFrame['index'] == [timestamp_index_list[i][1]]]],
                    ignore_index=True)

        count += 1

    roadDataFrame.reset_index(inplace=True)
    roadDataFrame.groupby('roadType').apply(func)

# %%
tree = ET.ElementTree(file='hefei_highways.osm')
root = tree.getroot()
# roadNameSet = getRoadNameSet(tree)
roadNameSet = set(['翡翠路','徽州大道','金寨路','芜湖路'])
# roadNameSet = set(['芜湖路'])
roadTable = pd.DataFrame(columns=['index', 'roadName', 'wayID', 'roadType', 'user', 'timestamp', 'version'])
roadDataFrame = constructRoadDataFrame(tree, roadNameSet)
for roadName,df in roadDataFrame.groupby('roadName'):
    count=0
    constructRoadTable(tree, df)
# Out:
# 正在处理第0条路： 徽州大道
# 正在处理第1条路： 金寨路
# 正在处理第2条路： 芜湖路
# 正在处理第3条路： 翡翠路
#     index roadName roadType             timestamp        user version  \
# 0       0     徽州大道  primary  2017-09-26T11:58:06Z  Austin Zhu      31
# 1       1     徽州大道  primary  2017-09-26T11:58:07Z  Austin Zhu      17
# 2       2     徽州大道  primary  2017-09-26T11:58:14Z  Austin Zhu      14
# 5       5     徽州大道  primary  2018-03-21T09:29:37Z      Newsta      13
# 6       6     徽州大道  primary  2017-09-26T11:58:20Z  Austin Zhu       7
# 7       7     徽州大道  primary  2017-09-26T11:58:20Z  Austin Zhu       5
# 8       8     徽州大道  primary  2018-03-21T09:07:24Z      Newsta      11
# 9       9     徽州大道  primary  2017-09-26T11:58:27Z  Austin Zhu      11
# 10     10     徽州大道  primary  2017-09-26T11:58:27Z  Austin Zhu       9
# 11     11     徽州大道  primary  2017-09-26T11:58:28Z  Austin Zhu      13
# 12     12     徽州大道  primary  2017-09-26T11:58:33Z  Austin Zhu       3
# 13     13     徽州大道  primary  2017-09-26T11:58:33Z  Austin Zhu       3
# 14     14     徽州大道  primary  2017-09-26T11:58:35Z  Austin Zhu       4
# 15     15     徽州大道  primary  2017-09-26T11:58:36Z  Austin Zhu       6
# 16     16     徽州大道  primary  2017-09-26T11:58:36Z  Austin Zhu       5
# 17     17     徽州大道  primary  2018-04-10T22:19:23Z  Virgil Guo       3
# 18     18     徽州大道  primary  2017-09-26T11:58:38Z  Austin Zhu       3
# 19     19     徽州大道  primary  2017-09-26T11:58:38Z  Austin Zhu       3
# 21     21     徽州大道  primary  2017-09-26T11:58:39Z  Austin Zhu       2
# 22     22     徽州大道  primary  2018-01-20T23:26:30Z  Virgil Guo       4
# 23     23     徽州大道  primary  2017-09-26T11:58:39Z  Austin Zhu       2
# 24     24     徽州大道  primary  2017-09-26T11:58:39Z  Austin Zhu       2
# 25     25     徽州大道  primary  2017-09-26T11:58:39Z  Austin Zhu       2
# 26     26     徽州大道  primary  2017-09-26T11:58:39Z  Austin Zhu       2
# 27     27     徽州大道  primary  2017-09-26T11:58:39Z  Austin Zhu       3
# 28     28     徽州大道  primary  2017-09-26T11:58:40Z  Austin Zhu       2
# 29     29     徽州大道  primary  2017-09-30T06:47:31Z  Austin Zhu       2
# 30     30     徽州大道  primary  2018-01-20T23:26:30Z  Virgil Guo       3
# 31     31     徽州大道  primary  2017-09-26T11:58:46Z  Austin Zhu       2
# 32     32     徽州大道  primary  2017-09-26T11:58:47Z  Austin Zhu       2
# 33     33     徽州大道  primary  2017-09-26T11:58:47Z  Austin Zhu       2
# 34     34     徽州大道  primary  2017-09-26T11:58:47Z  Austin Zhu       2
# 36     36     徽州大道  primary  2017-09-26T11:58:48Z  Austin Zhu       2
# 37     37     徽州大道  primary  2017-09-26T11:58:48Z  Austin Zhu       2
# 38     38     徽州大道  primary  2018-03-24T02:36:28Z  Virgil Guo       1
# 39     39     徽州大道  primary  2018-03-24T02:36:28Z  Virgil Guo       1
#
#         wayID
# 0    89922672
# 1   114279920
# 2   298565017
# 5   303071814
# 6   303072512
# 7   303072514
# 8   303073804
# 9   319978835
# 10  319978842
# 11  328170795
# 12  378670600
# 13  378670603
# 14  480620967
# 15  480620969
# 16  494705235
# 17  512283951
# 18  512283953
# 19  512283954
# 21  512284030
# 22  512284034
# 23  512284043
# 24  512284049
# 25  512284056
# 26  512284066
# 27  512284071
# 28  512326914
# 29  512326915
# 30  513484694
# 31  513484707
# 32  513967777
# 33  513967829
# 34  513967832
# 36  521996743
# 37  522163083
# 38  572497366
# 39  572497367
#     index roadName   roadType             timestamp        user version  \
# 35     35     徽州大道  secondary  2018-03-24T02:36:30Z  Virgil Guo       2
#
#         wayID
# 35  517718231
#    index roadName  roadType             timestamp        user version  \
# 3      3     徽州大道  tertiary  2018-03-24T02:36:30Z  Virgil Guo      18
#
#        wayID
# 3  298572972
#     index roadName roadType             timestamp        user version  \
# 4       4     徽州大道    trunk  2017-08-02T10:23:52Z  Virgil Guo      12
# 20     20     徽州大道    trunk  2017-08-02T10:23:42Z  Virgil Guo       1
#
#         wayID
# 4   303067754
# 20  512283958
#     index roadName roadType             timestamp         user version  \
# 0      89      翡翠路  primary  2017-08-29T14:10:08Z   Virgil Guo      21
# 1      90      翡翠路  primary  2016-02-19T00:24:55Z  Nodes&Roads       8
# 2      91      翡翠路  primary  2014-09-12T15:59:15Z          汤鹏程       3
# 3      92      翡翠路  primary  2016-05-31T15:11:03Z  Boyuan Yang       3
# 4      93      翡翠路  primary  2018-02-12T15:30:09Z  Seandebasti      17
# 5      94      翡翠路  primary  2017-08-29T14:10:09Z   Virgil Guo       9
# 6      95      翡翠路  primary  2016-05-31T15:11:02Z  Boyuan Yang       3
# 7      96      翡翠路  primary  2016-01-28T15:03:13Z   Virgil Guo       5
# 8      97      翡翠路  primary  2017-09-21T18:44:06Z   Virgil Guo       4
# 9      98      翡翠路  primary  2017-09-21T18:44:06Z   Virgil Guo       5
# 10     99      翡翠路  primary  2017-09-21T18:43:57Z   Virgil Guo       6
# 11    100      翡翠路  primary  2018-03-22T02:05:09Z   Virgil Guo       9
# 12    101      翡翠路  primary  2016-02-13T17:07:33Z   Virgil Guo       2
# 13    102      翡翠路  primary  2016-02-13T17:07:33Z   Virgil Guo       2
# 14    103      翡翠路  primary  2018-02-25T04:54:15Z   Virgil Guo      10
# 15    104      翡翠路  primary  2017-09-21T18:43:58Z   Virgil Guo      10
# 16    105      翡翠路  primary  2016-02-13T17:07:35Z   Virgil Guo       2
# 17    106      翡翠路  primary  2015-02-24T15:20:21Z          AUV       7
# 18    107      翡翠路  primary  2017-05-14T06:58:38Z   Virgil Guo      10
# 19    108      翡翠路  primary  2017-08-23T07:57:14Z   Virgil Guo       2
# 20    109      翡翠路  primary  2017-05-14T06:58:31Z   Virgil Guo       1
# 21    110      翡翠路  primary  2017-05-14T06:58:31Z   Virgil Guo       1
# 22    111      翡翠路  primary  2017-08-03T05:56:35Z   Virgil Guo       2
# 23    112      翡翠路  primary  2018-02-12T15:30:09Z  Seandebasti       2
# 24    113      翡翠路  primary  2017-08-23T07:57:03Z   Virgil Guo       1
# 25    114      翡翠路  primary  2017-09-16T05:45:11Z   Virgil Guo       3
# 26    115      翡翠路  primary  2017-08-23T07:57:07Z   Virgil Guo       1
# 27    116      翡翠路  primary  2017-08-29T14:09:59Z   Virgil Guo       1
# 28    117      翡翠路  primary  2017-08-29T14:10:00Z   Virgil Guo       1
# 29    118      翡翠路  primary  2017-08-29T14:10:05Z   Virgil Guo       1
# 30    119      翡翠路  primary  2017-09-21T18:43:49Z   Virgil Guo       1
# 31    120      翡翠路  primary  2017-09-21T18:43:49Z   Virgil Guo       1
# 32    121      翡翠路  primary  2017-09-21T18:43:52Z   Virgil Guo       1
# 33    122      翡翠路  primary  2017-09-21T18:43:52Z   Virgil Guo       1
#
#         wayID
# 0    24568371
# 1   115331105
# 2   115331106
# 3   115331108
# 4   243273757
# 5   246315658
# 6   290510409
# 7   290510410
# 8   290510412
# 9   303060220
# 10  303060221
# 11  303060222
# 12  303060223
# 13  303060224
# 14  303060225
# 15  303060428
# 16  303060429
# 17  324769654
# 18  324909396
# 19  493388195
# 20  493388196
# 21  493388197
# 22  493388198
# 23  517875576
# 24  517875577
# 25  517875623
# 26  517875625
# 27  519659345
# 28  519659351
# 29  519659443
# 30  526554801
# 31  526554802
# 32  526554831
# 33  526554833
#     index roadName roadType             timestamp        user version  \
# 0      75      芜湖路  primary  2017-08-07T05:37:07Z  Virgil Guo      24
# 1      76      芜湖路  primary  2017-08-07T05:37:07Z  Virgil Guo       8
# 2      77      芜湖路  primary  2017-08-03T01:46:38Z  Virgil Guo      16
# 3      78      芜湖路  primary  2018-03-14T03:45:06Z     LJpnice       7
# 5      80      芜湖路  primary  2017-08-03T01:46:38Z  Virgil Guo       5
# 6      81      芜湖路  primary  2017-08-03T01:46:39Z  Virgil Guo       3
# 7      82      芜湖路  primary  2018-03-21T08:14:27Z      Newsta       4
# 8      83      芜湖路  primary  2017-08-03T01:46:35Z  Virgil Guo       1
# 9      84      芜湖路  primary  2017-08-07T05:36:59Z  Virgil Guo       1
# 10     85      芜湖路  primary  2018-03-21T08:14:27Z      Newsta       2
# 11     86      芜湖路  primary  2018-03-14T03:45:06Z     LJpnice       2
# 12     87      芜湖路  primary  2018-03-14T03:45:04Z     LJpnice       1
# 13     88      芜湖路  primary  2018-03-14T03:45:05Z     LJpnice       1
#
#         wayID
# 0   131879722
# 1   305825596
# 2   305826738
# 3   325354955
# 5   353449882
# 6   422589225
# 7   512417228
# 8   512417229
# 9   513484683
# 10  513484684
# 11  513484711
# 12  569498914
# 13  569498916
#    index roadName   roadType             timestamp     user version      wayID
# 4     79      芜湖路  secondary  2018-03-14T03:45:06Z  LJpnice       4  328128650
#     index roadName roadType             timestamp         user version  \
# 8      48      金寨路  primary  2018-02-12T03:27:49Z  Seandebasti      14
# 21     61      金寨路  primary  2017-09-26T10:34:26Z   Austin Zhu       2
#
#         wayID
# 8   325126415
# 21  512460897
#     index roadName roadType             timestamp         user version  \
# 0      40      金寨路    trunk  2018-04-10T22:19:18Z   Virgil Guo      31
# 1      41      金寨路    trunk  2017-10-30T02:16:53Z   Austin Zhu      40
# 2      42      金寨路    trunk  2016-02-13T16:44:23Z   Virgil Guo      10
# 3      43      金寨路    trunk  2014-09-07T15:24:36Z          汤鹏程       4
# 4      44      金寨路    trunk  2015-05-19T16:30:47Z    dannykath       2
# 5      45      金寨路    trunk  2016-02-13T16:44:24Z   Virgil Guo       6
# 7      47      金寨路    trunk  2017-10-30T02:52:00Z   Austin Zhu       8
# 9      49      金寨路    trunk  2017-10-30T02:52:00Z   Austin Zhu      21
# 10     50      金寨路    trunk  2015-01-29T05:06:36Z          AUV       1
# 11     51      金寨路    trunk  2018-03-14T03:45:06Z      LJpnice      18
# 12     52      金寨路    trunk  2017-10-30T03:22:47Z   Austin Zhu       3
# 13     53      金寨路    trunk  2017-10-30T03:22:47Z   Austin Zhu       5
# 14     54      金寨路    trunk  2018-03-13T01:49:57Z       Newsta       9
# 15     55      金寨路    trunk  2017-10-30T03:22:47Z   Austin Zhu       4
# 16     56      金寨路    trunk  2017-10-30T03:22:47Z   Austin Zhu       2
# 17     57      金寨路    trunk  2017-10-30T03:22:49Z   Austin Zhu       3
# 18     58      金寨路    trunk  2018-03-12T08:05:49Z       Newsta       8
# 19     59      金寨路    trunk  2017-10-30T03:22:50Z   Austin Zhu       3
# 20     60      金寨路    trunk  2018-02-12T03:27:49Z  Seandebasti       5
# 22     62      金寨路    trunk  2017-10-30T03:22:50Z   Austin Zhu       6
# 23     63      金寨路    trunk  2017-10-30T03:22:54Z   Austin Zhu       3
# 24     64      金寨路    trunk  2017-10-30T03:22:54Z   Austin Zhu       3
# 25     65      金寨路    trunk  2017-10-30T03:22:55Z   Austin Zhu       3
# 26     66      金寨路    trunk  2017-10-30T03:22:55Z   Austin Zhu       3
# 27     67      金寨路    trunk  2018-03-14T03:45:05Z      LJpnice       3
# 28     68      金寨路    trunk  2017-10-30T03:24:53Z   Austin Zhu       2
# 29     69      金寨路    trunk  2018-04-10T22:19:17Z   Virgil Guo       3
# 30     70      金寨路    trunk  2017-10-30T03:24:53Z   Austin Zhu       2
# 31     71      金寨路    trunk  2018-03-12T08:05:49Z       Newsta       2
# 32     72      金寨路    trunk  2018-03-12T08:05:47Z       Newsta       1
# 33     73      金寨路    trunk  2018-03-12T08:05:48Z       Newsta       1
# 34     74      金寨路    trunk  2018-03-14T03:45:04Z      LJpnice       1
#
#         wayID
# 0   107203326
# 1   107502897
# 2   252129342
# 3   252129343
# 4   302277608
# 5   302277611
# 7   325126409
# 9   325126416
# 10  325126425
# 11  325354956
# 12  512262926
# 13  512262927
# 14  512262934
# 15  512262935
# 16  512284142
# 17  512417226
# 18  512417250
# 19  512460876
# 20  512460878
# 22  512460900
# 23  513948044
# 24  513948048
# 25  513948126
# 26  513948127
# 27  526571548
# 28  526571634
# 29  526571637
# 30  526581122
# 31  568043837
# 32  568877567
# 33  568877568
# 34  569498915
#    index roadName    roadType             timestamp        user version  \
# 6     46      金寨路  trunk_link  2017-05-06T12:23:19Z  Virgil Guo       2
#
#        wayID
# 6  325126408

# %%
roadTable
# Out:
#    index roadName    roadType             timestamp         user version  \
# 0     17     徽州大道     primary  2018-04-10T22:19:23Z   Virgil Guo       3
# 1      5     徽州大道     primary  2018-03-21T09:29:37Z       Newsta      13
# 2     29     徽州大道     primary  2017-09-30T06:47:31Z   Austin Zhu       2
# 3     35     徽州大道   secondary  2018-03-24T02:36:30Z   Virgil Guo       2
# 4      3     徽州大道    tertiary  2018-03-24T02:36:30Z   Virgil Guo      18
# 5      4     徽州大道       trunk  2017-08-02T10:23:52Z   Virgil Guo      12
# 6    100      翡翠路     primary  2018-03-22T02:05:09Z   Virgil Guo       9
# 7     93      翡翠路     primary  2018-02-12T15:30:09Z  Seandebasti      17
# 8     92      翡翠路     primary  2016-05-31T15:11:03Z  Boyuan Yang       3
# 9     82      芜湖路     primary  2018-03-21T08:14:27Z       Newsta       4
# 10    78      芜湖路     primary  2018-03-14T03:45:06Z      LJpnice       7
# 11    75      芜湖路     primary  2017-08-07T05:37:07Z   Virgil Guo      24
# 12    79      芜湖路   secondary  2018-03-14T03:45:06Z      LJpnice       4
# 13    48      金寨路     primary  2018-02-12T03:27:49Z  Seandebasti      14
# 14    61      金寨路     primary  2017-09-26T10:34:26Z   Austin Zhu       2
# 15    40      金寨路       trunk  2018-04-10T22:19:18Z   Virgil Guo      31
# 16    51      金寨路       trunk  2018-03-14T03:45:06Z      LJpnice      18
# 17    54      金寨路       trunk  2018-03-13T01:49:57Z       Newsta       9
# 18    46      金寨路  trunk_link  2017-05-06T12:23:19Z   Virgil Guo       2
#
#         wayID
# 0   512283951
# 1   303071814
# 2   512326915
# 3   517718231
# 4   298572972
# 5   303067754
# 6   303060222
# 7   243273757
# 8   115331108
# 9   512417228
# 10  325354955
# 11  131879722
# 12  328128650
# 13  325126415
# 14  512460897
# 15  107203326
# 16  325354956
# 17  512262934
# 18  325126408
